# %% [markdown]
# # Volumetry Analysis
# ## Data:
#     - 1. Freesurfer results: ICV. Lh/Rh_cerebellum_gm/wm (generated by "collect_volumes.sh" script);
#         - Left/ Right cerebellum gray/white matter volumes
#     - 2. Cerebellar SUIT segmentation with SUIT and MDTB atlas;
#          - SUIT: Vermis VI, Vermis_CrusI,  Vermis_CrusII, CrusI, CrusII, Dentate nucleus;
#          - MBTB: MDTB functional regions 1,2,4,5;
#     - 3. Cerebellar MAGeTBrain [MAGeTBrain pipeline](https://github.com/CobraLab/documentation/wiki/MAGeTBrain#collecting-volumes)
#         - MAGeT: Vermis VI, Vermis_CrusI,  Vermis_CrusII, CrusI, CrusII, Dentate nucleus;
#
# ## Cohorts
# - Current cohort: MNI ET/NC (38/32), QC not included.
#
# ## Tasks
# - Compare total cerebellar volumes (left and right)
# - Compare lobule volumes (13 per hemisphere)
#
# ## Covariates
# - Age, Sex, site, eTIV

# %%
## read demographic data and freesurfer outputs
from pathlib import Path
import nipype.interfaces.io as nio
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data_dir = Path("/codes/tab_data")
mni_file  = data_dir/'MNI_Des-cere_preped.csv'
adni_ppmi_file = data_dir/'ADNI-PPMI_Des-cere_preped.csv'

mni_df       = pd.read_csv(mni_file , sep=',', header=0, index_col=0);
adni_ppmi_df = pd.read_csv(adni_ppmi_file , sep=',', header=0, index_col=0);

#excluding list
data_df = pd.concat([mni_df, adni_ppmi_df])
drop_col_list = ['Left_WM_hypointensities', 'Right_WM_hypointensities', '5th_Ventricle'];
data_df=data_df.drop(columns=drop_col_list);
# Out:
# 210926-06:08:50,12 nipype.utils WARNING:
# 	 A newer version (1.5.1) of nipy/nipype is available. You are using 1.5.0

# %%
# prepare data for this script
SUIT_labels = ['Left_I_IV','Right_I_IV','Left_V','Right_V','Left_VI','Vermis_VI','Right_VI','Left_CrusI','Vermis_CrusI','Right_CrusI','Left_CrusII','Vermis_CrusII','Right_CrusII','Left_VIIb','Vermis_VIIb','Right_VIIb','Left_VIIIa','Vermis_VIIIa','Right_VIIIa','Left_VIIIb','Vermis_VIIIb','Right_VIIIb','Left_IX','Vermis_IX','Right_IX','Left_X','Vermis_X','Right_X','Left_Dentate','Right_Dentate','Left_Interposed','Right_Interposed','Left_Fastigial','Right_Fastigial'];
SUIT_labels = [ x.replace('-','_') for x in SUIT_labels]
SUIT_l_labels = ['Left_I_IV',  'Left_V', 'Left_VI', 'Left_CrusI', 'Left_CrusII', 'Left_VIIb', 'Left_VIIIa', 'Left_VIIIb', 'Left_IX', 'Left_X', 'Left_Dentate', 'Left_Interposed', 'Left_Fastigial'];
SUIT_r_labels = ['Right_I_IV','Right_V','Right_VI','Right_CrusI','Right_CrusII','Right_VIIb','Right_VIIIa','Right_VIIIb','Right_IX','Right_X','Right_Dentate','Right_Interposed','Right_Fastigial'];
SUIT_v_labels = ['Vermis_VI', 'Vermis_CrusI', 'Vermis_CrusII', 'Vermis_VIIb', 'Vermis_VIIIa','Vermis_VIIIb', 'Vermis_IX', 'Vermis_X'];
MDTB_labels   = ['MDTB_'+str(x+1) for x in range(10)];
analysis_list = ['age','sex','group','site','eTIV','SupraTentorialVol', 'SupraTentorialVolNotVent',
                 'Left_Cerebellum_White_Matter','Left_Cerebellum_Cortex','Right_Cerebellum_White_Matter','Right_Cerebellum_Cortex']+SUIT_l_labels+SUIT_r_labels+SUIT_v_labels+MDTB_labels
curr_df = data_df.loc[:,analysis_list]
curr_df.loc[:,'Cerebellum_White_Matter']=curr_df['Left_Cerebellum_White_Matter']+curr_df['Right_Cerebellum_White_Matter'];
curr_df.loc[:,'Cerebellum_Cortex']=curr_df['Left_Cerebellum_Cortex']+curr_df['Right_Cerebellum_Cortex'];
#print(list(data_df.columns))

# %%
### statistical analysis
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from utils_et_biomarker.utils import ctr_tiv, glm_test, rep_model, ctr_by_nc, cal_es

# calculate the Infra tentorial volumen approximately by eTIV-SupraTentorialVol
curr_df.loc[:,'InfraTentorialVol']=curr_df['eTIV']-curr_df['SupraTentorialVol'];
# get the data for ET/NC analysis
df = curr_df[(curr_df['group']=='ET')|(curr_df['group']=='NC')].copy()
# get indicator variable
df.loc[:,'male']=[int(x=='M') for x in df['sex']]
alpha_=5; n_permu_=5000;

## covariate
info_list=['age','sex','group','site','eTIV','SupraTentorialVol', 'SupraTentorialVolNotVent','InfraTentorialVol']
cerebellum_list = ['Left_Cerebellum_Cortex','Left_Cerebellum_White_Matter',
                   'Right_Cerebellum_Cortex','Right_Cerebellum_White_Matter',
                   'Cerebellum_Cortex','Cerebellum_White_Matter'];
lobular_list = ['Vermis_VI', 'Vermis_CrusI', 'Vermis_CrusII', 
                'Left_CrusI', 'Right_CrusI', 'Left_CrusII', 'Right_CrusII','Left_Dentate', 'Right_Dentate',
                'MDTB_1', 'MDTB_2', 'MDTB_4', 'MDTB_5'];

sts_df = df[info_list+cerebellum_list+lobular_list].copy();
tar_list = cerebellum_list+lobular_list;

sts_tests_list = ['Cohen_d', 'rank_sum']; 
group_mni_list = ['ET','NC'];

# %% [markdown]
# ## Volumentry analysis for cerebellar volumetry for ET
#     1. Experiment 1: without controling for any covariates;
#     2. Experiment 2: control age/sex/eTIV with rm control group method;
#     3. Experiment 3: control age/sex/infratentorialVolume with rm control group method;
#     2. Experiment 4: control age/sex/eTIV with direct proportion adjustment method;
#     3. Experiment 5: control age/sex/infratentorialVolume with direct proportion adjustment method;

# %%
# Experiment 1: volumentry analysis for cerebellar gray and white matter without correction.
res_cere_gw = cal_es(df, tar_list, alpha_, n_permu_, sts_tests_list, group_mni_list);

C_MAP='coolwarm_r'; VMIN=0; VMAX=0.1;
vis_df = res_cere_gw.copy()
#vis_df['ROI']=vis_df['ROI'].map(lambda x: x[0:-14]);
es_df=vis_df[['ROI','test','ES']]; p_df=vis_df[['ROI','test','p_val']]
es_df = es_df.pivot("ROI", "test"); p_df = p_df.pivot("ROI", "test"); 
# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
ax1=sns.heatmap(p_df, annot=es_df, fmt=".4f", linewidths=.5, cmap=C_MAP, vmin=VMIN, vmax=VMAX, ax=ax)
ax1.set_title('ET and NC Cerebellum Volemetry with no confounder control')
display(res_cere_gw)
# Out:
#           ES                            ROI  group     p_val      test
# 0  -0.107637         Left_Cerebellum_Cortex  ET_NC  0.661600   Cohen_d
# 1  -0.176842         Left_Cerebellum_Cortex  ET_NC  0.859632  rank_sum
# 2  -0.079666   Left_Cerebellum_White_Matter  ET_NC  0.718000   Cohen_d
# 3  -0.271158   Left_Cerebellum_White_Matter  ET_NC  0.786269  rank_sum
# 4  -0.189353        Right_Cerebellum_Cortex  ET_NC  0.452400   Cohen_d
# 5  -0.554106        Right_Cerebellum_Cortex  ET_NC  0.579507  rank_sum
# 6  -0.382987  Right_Cerebellum_White_Matter  ET_NC  0.116000   Cohen_d
# 7  -1.461896  Right_Cerebellum_White_Matter  ET_NC  0.143770  rank_sum
# 8  -0.151184              Cerebellum_Cortex  ET_NC  0.554000   Cohen_d
# 9  -0.389053              Cerebellum_Cortex  ET_NC  0.697237  rank_sum
# 10 -0.234761        Cerebellum_White_Matter  ET_NC  0.330800   Cohen_d
# 11 -0.742737        Cerebellum_White_Matter  ET_NC  0.457641  rank_sum
# 12  0.039534                      Vermis_VI  ET_NC  0.872000   Cohen_d
# 13  0.459790                      Vermis_VI  ET_NC  0.645667  rank_sum
# 14  0.386741                   Vermis_CrusI  ET_NC  0.122800   Cohen_d
# 15  1.650527                   Vermis_CrusI  ET_NC  0.098835  rank_sum
# 16  0.133590                  Vermis_CrusII  ET_NC  0.568000   Cohen_d
# 17  0.430316                  Vermis_CrusII  ET_NC  0.666966  rank_sum
# 18  0.306312                     Left_CrusI  ET_NC  0.205200   Cohen_d
# 19  1.461896                     Left_CrusI  ET_NC  0.143770  rank_sum
# 20  0.163534                    Right_CrusI  ET_NC  0.503200   Cohen_d
# 21  0.943158                    Right_CrusI  ET_NC  0.345600  rank_sum
# 22  0.093836                    Left_CrusII  ET_NC  0.702000   Cohen_d
# 23  0.907790                    Left_CrusII  ET_NC  0.363989  rank_sum
# 24 -0.038618                   Right_CrusII  ET_NC  0.882000   Cohen_d
# 25  0.695579                   Right_CrusII  ET_NC  0.486692  rank_sum
# 26  0.044930                   Left_Dentate  ET_NC  0.851600   Cohen_d
# 27  0.041263                   Left_Dentate  ET_NC  0.967086  rank_sum
# 28 -0.090716                  Right_Dentate  ET_NC  0.692800   Cohen_d
# 29 -0.489263                  Right_Dentate  ET_NC  0.624655  rank_sum
# 30  0.100419                         MDTB_1  ET_NC  0.670800   Cohen_d
# 31  0.636632                         MDTB_1  ET_NC  0.524365  rank_sum
# 32  0.128154                         MDTB_2  ET_NC  0.590800   Cohen_d
# 33  0.736843                         MDTB_2  ET_NC  0.461218  rank_sum
# 34  0.063650                         MDTB_4  ET_NC  0.804000   Cohen_d
# 35  0.837053                         MDTB_4  ET_NC  0.402563  rank_sum
# 36  0.175800                         MDTB_5  ET_NC  0.470400   Cohen_d
# 37  1.108211                         MDTB_5  ET_NC  0.267771  rank_sum

# %%
# Experiment 2: volumentry analysis for cerebellar gray and white matter for ET controling age/set/eTIV with rm_norm. 
dat_cere_gw, cere_gw_col = ctr_tiv(df, tar_list, 'eTIV', ['age','male'], 'rm_norm')
res_cere_gw = cal_es(dat_cere_gw, cere_gw_col, alpha_, n_permu_, sts_tests_list, group_mni_list);

C_MAP='coolwarm_r'; VMIN=0; VMAX=0.1;
vis_df = res_cere_gw.copy()
vis_df['ROI']=vis_df['ROI'].map(lambda x: x[0:-14]);
es_df=vis_df[['ROI','test','ES']]; p_df=vis_df[['ROI','test','p_val']]
es_df = es_df.pivot("ROI", "test"); p_df = p_df.pivot("ROI", "test"); 
# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
ax1=sns.heatmap(p_df, annot=es_df, fmt=".4f", linewidths=.5, cmap=C_MAP, vmin=VMIN, vmax=VMAX, ax=ax)
ax1.set_title('ET and NC Cerebellum Volemetry after control age, sex and eTIV with rm_norm')
display(res_cere_gw)
# Out:
# Using  rm_norm
# New columns 19 :  ['Left_Cerebellum_Cortex_eTIV_age_male', 'Left_Cerebellum_White_Matter_eTIV_age_male', 'Right_Cerebellum_Cortex_eTIV_age_male', 'Right_Cerebellum_White_Matter_eTIV_age_male', 'Cerebellum_Cortex_eTIV_age_male', 'Cerebellum_White_Matter_eTIV_age_male', 'Vermis_VI_eTIV_age_male', 'Vermis_CrusI_eTIV_age_male', 'Vermis_CrusII_eTIV_age_male', 'Left_CrusI_eTIV_age_male', 'Right_CrusI_eTIV_age_male', 'Left_CrusII_eTIV_age_male', 'Right_CrusII_eTIV_age_male', 'Left_Dentate_eTIV_age_male', 'Right_Dentate_eTIV_age_male', 'MDTB_1_eTIV_age_male', 'MDTB_2_eTIV_age_male', 'MDTB_4_eTIV_age_male', 'MDTB_5_eTIV_age_male']
#           ES                                          ROI  group     p_val  \
# 0   0.253320         Left_Cerebellum_Cortex_eTIV_age_male  ET_NC  0.293600
# 1   1.025685         Left_Cerebellum_Cortex_eTIV_age_male  ET_NC  0.305040
# 2  -0.234569   Left_Cerebellum_White_Matter_eTIV_age_male  ET_NC  0.323600
# 3  -0.978527   Left_Cerebellum_White_Matter_eTIV_age_male  ET_NC  0.327814
# 4   0.121597        Right_Cerebellum_Cortex_eTIV_age_male  ET_NC  0.628000
# 5   0.565895        Right_Cerebellum_Cortex_eTIV_age_male  ET_NC  0.571465
# 6  -0.436856  Right_Cerebellum_White_Matter_eTIV_age_male  ET_NC  0.073600
# 7  -1.744843  Right_Cerebellum_White_Matter_eTIV_age_male  ET_NC  0.081012
# 8   0.190577              Cerebellum_Cortex_eTIV_age_male  ET_NC  0.426000
# 9   0.872422              Cerebellum_Cortex_eTIV_age_male  ET_NC  0.382978
# 10 -0.342714        Cerebellum_White_Matter_eTIV_age_male  ET_NC  0.158000
# 11 -1.544422        Cerebellum_White_Matter_eTIV_age_male  ET_NC  0.122486
# 12  0.122505                      Vermis_VI_eTIV_age_male  ET_NC  0.602000
# 13  0.742737                      Vermis_VI_eTIV_age_male  ET_NC  0.457641
# 14  0.115296                   Vermis_CrusI_eTIV_age_male  ET_NC  0.650000
# 15  0.448000                   Vermis_CrusI_eTIV_age_male  ET_NC  0.654153
# 16 -0.260450                  Vermis_CrusII_eTIV_age_male  ET_NC  0.274000
# 17 -1.355790                  Vermis_CrusII_eTIV_age_male  ET_NC  0.175166
# 18  0.619134                     Left_CrusI_eTIV_age_male  ET_NC  0.010800
# 19  2.192843                     Left_CrusI_eTIV_age_male  ET_NC  0.028319
# 20  0.461163                    Right_CrusI_eTIV_age_male  ET_NC  0.060800
# 21  2.122106                    Right_CrusI_eTIV_age_male  ET_NC  0.033829
# 22  0.328753                    Left_CrusII_eTIV_age_male  ET_NC  0.184400
# 23  1.273264                    Left_CrusII_eTIV_age_male  ET_NC  0.202924
# 24  0.211821                   Right_CrusII_eTIV_age_male  ET_NC  0.402000
# 25  0.966737                   Right_CrusII_eTIV_age_male  ET_NC  0.333675
# 26 -0.320318                   Left_Dentate_eTIV_age_male  ET_NC  0.191200
# 27 -1.721264                   Left_Dentate_eTIV_age_male  ET_NC  0.085203
# 28 -0.503823                  Right_Dentate_eTIV_age_male  ET_NC  0.035600
# 29 -2.522949                  Right_Dentate_eTIV_age_male  ET_NC  0.011638
# 30  0.392987                         MDTB_1_eTIV_age_male  ET_NC  0.106000
# 31  1.520843                         MDTB_1_eTIV_age_male  ET_NC  0.128299
# 32  0.390122                         MDTB_2_eTIV_age_male  ET_NC  0.107600
# 33  1.615159                         MDTB_2_eTIV_age_male  ET_NC  0.106276
# 34  0.425289                         MDTB_4_eTIV_age_male  ET_NC  0.083200
# 35  1.709475                         MDTB_4_eTIV_age_male  ET_NC  0.087363
# 36  0.555118                         MDTB_5_eTIV_age_male  ET_NC  0.024400
# 37  1.886317                         MDTB_5_eTIV_age_male  ET_NC  0.059252
#
#         test
# 0    Cohen_d
# 1   rank_sum
# 2    Cohen_d
# 3   rank_sum
# 4    Cohen_d
# 5   rank_sum
# 6    Cohen_d
# 7   rank_sum
# 8    Cohen_d
# 9   rank_sum
# 10   Cohen_d
# 11  rank_sum
# 12   Cohen_d
# 13  rank_sum
# 14   Cohen_d
# 15  rank_sum
# 16   Cohen_d
# 17  rank_sum
# 18   Cohen_d
# 19  rank_sum
# 20   Cohen_d
# 21  rank_sum
# 22   Cohen_d
# 23  rank_sum
# 24   Cohen_d
# 25  rank_sum
# 26   Cohen_d
# 27  rank_sum
# 28   Cohen_d
# 29  rank_sum
# 30   Cohen_d
# 31  rank_sum
# 32   Cohen_d
# 33  rank_sum
# 34   Cohen_d
# 35  rank_sum
# 36   Cohen_d
# 37  rank_sum

# %%
# Experiment 3: volumentry analysis for cerebellar volumentry for ET/NC, controling for age/sex/infratentorial
dat_cere_gw, cere_gw_col = ctr_tiv(df, tar_list, 'InfraTentorialVol', ['age','male'], 'rm_norm')
res_cere_gw = cal_es(dat_cere_gw, cere_gw_col, alpha_, n_permu_, sts_tests_list, group_mni_list);

C_MAP='coolwarm_r'; VMIN=0; VMAX=0.1;
vis_df = res_cere_gw.copy()
vis_df['ROI']=vis_df['ROI'].map(lambda x: x[0:-27]);
es_df=vis_df[['ROI','test','ES']]; p_df=vis_df[['ROI','test','p_val']]
es_df = es_df.pivot("ROI", "test"); p_df = p_df.pivot("ROI", "test"); 
# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
ax1=sns.heatmap(p_df, annot=es_df, fmt=".4f", linewidths=.5, cmap=C_MAP, vmin=VMIN, vmax=VMAX, ax=ax)
ax1.set_title('ET and NC Cerebellum Volemetry after control age, sex and InfraTentorialVol with rm_norm')
display(res_cere_gw)
# Out:
# Using  rm_norm
# New columns 19 :  ['Left_Cerebellum_Cortex_InfraTentorialVol_age_male', 'Left_Cerebellum_White_Matter_InfraTentorialVol_age_male', 'Right_Cerebellum_Cortex_InfraTentorialVol_age_male', 'Right_Cerebellum_White_Matter_InfraTentorialVol_age_male', 'Cerebellum_Cortex_InfraTentorialVol_age_male', 'Cerebellum_White_Matter_InfraTentorialVol_age_male', 'Vermis_VI_InfraTentorialVol_age_male', 'Vermis_CrusI_InfraTentorialVol_age_male', 'Vermis_CrusII_InfraTentorialVol_age_male', 'Left_CrusI_InfraTentorialVol_age_male', 'Right_CrusI_InfraTentorialVol_age_male', 'Left_CrusII_InfraTentorialVol_age_male', 'Right_CrusII_InfraTentorialVol_age_male', 'Left_Dentate_InfraTentorialVol_age_male', 'Right_Dentate_InfraTentorialVol_age_male', 'MDTB_1_InfraTentorialVol_age_male', 'MDTB_2_InfraTentorialVol_age_male', 'MDTB_4_InfraTentorialVol_age_male', 'MDTB_5_InfraTentorialVol_age_male']
#           ES                                                ROI  group  \
# 0  -0.123200  Left_Cerebellum_Cortex_InfraTentorialVol_age_male  ET_NC
# 1  -0.742737  Left_Cerebellum_Cortex_InfraTentorialVol_age_male  ET_NC
# 2   0.091736  Left_Cerebellum_White_Matter_InfraTentorialVol...  ET_NC
# 3   0.530527  Left_Cerebellum_White_Matter_InfraTentorialVol...  ET_NC
# 4  -0.320332  Right_Cerebellum_Cortex_InfraTentorialVol_age_...  ET_NC
# 5  -1.367580  Right_Cerebellum_Cortex_InfraTentorialVol_age_...  ET_NC
# 6  -0.113826  Right_Cerebellum_White_Matter_InfraTentorialVo...  ET_NC
# 7  -0.259369  Right_Cerebellum_White_Matter_InfraTentorialVo...  ET_NC
# 8  -0.227534       Cerebellum_Cortex_InfraTentorialVol_age_male  ET_NC
# 9  -1.084632       Cerebellum_Cortex_InfraTentorialVol_age_male  ET_NC
# 10 -0.009507  Cerebellum_White_Matter_InfraTentorialVol_age_...  ET_NC
# 11  0.259369  Cerebellum_White_Matter_InfraTentorialVol_age_...  ET_NC
# 12 -0.346730               Vermis_VI_InfraTentorialVol_age_male  ET_NC
# 13 -1.155369               Vermis_VI_InfraTentorialVol_age_male  ET_NC
# 14  0.007959            Vermis_CrusI_InfraTentorialVol_age_male  ET_NC
# 15  0.047158            Vermis_CrusI_InfraTentorialVol_age_male  ET_NC
# 16 -0.540494           Vermis_CrusII_InfraTentorialVol_age_male  ET_NC
# 17 -2.287159           Vermis_CrusII_InfraTentorialVol_age_male  ET_NC
# 18  0.463593              Left_CrusI_InfraTentorialVol_age_male  ET_NC
# 19  1.674106              Left_CrusI_InfraTentorialVol_age_male  ET_NC
# 20  0.317358             Right_CrusI_InfraTentorialVol_age_male  ET_NC
# 21  1.438317             Right_CrusI_InfraTentorialVol_age_male  ET_NC
# 22  0.235146             Left_CrusII_InfraTentorialVol_age_male  ET_NC
# 23  1.273264             Left_CrusII_InfraTentorialVol_age_male  ET_NC
# 24  0.144254            Right_CrusII_InfraTentorialVol_age_male  ET_NC
# 25  1.226106            Right_CrusII_InfraTentorialVol_age_male  ET_NC
# 26 -0.164690            Left_Dentate_InfraTentorialVol_age_male  ET_NC
# 27 -1.084632            Left_Dentate_InfraTentorialVol_age_male  ET_NC
# 28 -0.425005           Right_Dentate_InfraTentorialVol_age_male  ET_NC
# 29 -1.980633           Right_Dentate_InfraTentorialVol_age_male  ET_NC
# 30  0.166476                  MDTB_1_InfraTentorialVol_age_male  ET_NC
# 31  0.742737                  MDTB_1_InfraTentorialVol_age_male  ET_NC
# 32  0.197595                  MDTB_2_InfraTentorialVol_age_male  ET_NC
# 33  0.813474                  MDTB_2_InfraTentorialVol_age_male  ET_NC
# 34  0.319766                  MDTB_4_InfraTentorialVol_age_male  ET_NC
# 35  1.497264                  MDTB_4_InfraTentorialVol_age_male  ET_NC
# 36  0.522592                  MDTB_5_InfraTentorialVol_age_male  ET_NC
# 37  2.240001                  MDTB_5_InfraTentorialVol_age_male  ET_NC
#
#        p_val      test
# 0   0.636800   Cohen_d
# 1   0.457641  rank_sum
# 2   0.687200   Cohen_d
# 3   0.595747  rank_sum
# 4   0.188800   Cohen_d
# 5   0.171444  rank_sum
# 6   0.628000   Cohen_d
# 7   0.795351  rank_sum
# 8   0.346800   Cohen_d
# 9   0.278085  rank_sum
# 10  0.943200   Cohen_d
# 11  0.795351  rank_sum
# 12  0.146800   Cohen_d
# 13  0.247939  rank_sum
# 14  0.983200   Cohen_d
# 15  0.962387  rank_sum
# 16  0.030400   Cohen_d
# 17  0.022187  rank_sum
# 18  0.060400   Cohen_d
# 19  0.094110  rank_sum
# 20  0.195200   Cohen_d
# 21  0.150344  rank_sum
# 22  0.337200   Cohen_d
# 23  0.202924  rank_sum
# 24  0.557600   Cohen_d
# 25  0.220159  rank_sum
# 26  0.482800   Cohen_d
# 27  0.278085  rank_sum
# 28  0.086800   Cohen_d
# 29  0.047632  rank_sum
# 30  0.488400   Cohen_d
# 31  0.457641  rank_sum
# 32  0.414800   Cohen_d
# 33  0.415946  rank_sum
# 34  0.194800   Cohen_d
# 35  0.134325  rank_sum
# 36  0.030400   Cohen_d
# 37  0.025091  rank_sum

# %%
# Experiment 4: volumentry analysis for cerebellar gray and white matter for ET
dat_cere_gw, cere_gw_col = ctr_tiv(df, tar_list, 'eTIV', ['age','male'], 'dpa')
res_cere_gw = cal_es(dat_cere_gw, cere_gw_col[int(len(cere_gw_col)/2):], alpha_, n_permu_, sts_tests_list, group_mni_list);

C_MAP='coolwarm_r'; VMIN=0; VMAX=0.1;
vis_df = res_cere_gw.copy()
vis_df['ROI']=vis_df['ROI'].map(lambda x: x[0:-9]);
es_df=vis_df[['ROI','test','ES']]; p_df=vis_df[['ROI','test','p_val']]
es_df = es_df.pivot("ROI", "test"); p_df = p_df.pivot("ROI", "test"); 
# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
ax1=sns.heatmap(p_df, annot=es_df, fmt=".4f", linewidths=.5, cmap=C_MAP, vmin=VMIN, vmax=VMAX, ax=ax)
ax1.set_title('ET and NC Cerebellum Volemetry after control age, sex and eTIV with dpa')
display(res_cere_gw)
# Out:
# Using  dpa
# New columns 38 :  ['Left_Cerebellum_Cortex_dpa', 'Left_Cerebellum_White_Matter_dpa', 'Right_Cerebellum_Cortex_dpa', 'Right_Cerebellum_White_Matter_dpa', 'Cerebellum_Cortex_dpa', 'Cerebellum_White_Matter_dpa', 'Vermis_VI_dpa', 'Vermis_CrusI_dpa', 'Vermis_CrusII_dpa', 'Left_CrusI_dpa', 'Right_CrusI_dpa', 'Left_CrusII_dpa', 'Right_CrusII_dpa', 'Left_Dentate_dpa', 'Right_Dentate_dpa', 'MDTB_1_dpa', 'MDTB_2_dpa', 'MDTB_4_dpa', 'MDTB_5_dpa', 'Left_Cerebellum_Cortex_dpa_age_male', 'Left_Cerebellum_White_Matter_dpa_age_male', 'Right_Cerebellum_Cortex_dpa_age_male', 'Right_Cerebellum_White_Matter_dpa_age_male', 'Cerebellum_Cortex_dpa_age_male', 'Cerebellum_White_Matter_dpa_age_male', 'Vermis_VI_dpa_age_male', 'Vermis_CrusI_dpa_age_male', 'Vermis_CrusII_dpa_age_male', 'Left_CrusI_dpa_age_male', 'Right_CrusI_dpa_age_male', 'Left_CrusII_dpa_age_male', 'Right_CrusII_dpa_age_male', 'Left_Dentate_dpa_age_male', 'Right_Dentate_dpa_age_male', 'MDTB_1_dpa_age_male', 'MDTB_2_dpa_age_male', 'MDTB_4_dpa_age_male', 'MDTB_5_dpa_age_male']
#           ES                                         ROI  group     p_val  \
# 0   0.187012         Left_Cerebellum_Cortex_dpa_age_male  ET_NC  0.452000
# 1   0.589474         Left_Cerebellum_Cortex_dpa_age_male  ET_NC  0.555543
# 2  -0.319147   Left_Cerebellum_White_Matter_dpa_age_male  ET_NC  0.184800
# 3  -1.344001   Left_Cerebellum_White_Matter_dpa_age_male  ET_NC  0.178948
# 4   0.011655        Right_Cerebellum_Cortex_dpa_age_male  ET_NC  0.971200
# 5  -0.106105        Right_Cerebellum_Cortex_dpa_age_male  ET_NC  0.915499
# 6  -0.505099  Right_Cerebellum_White_Matter_dpa_age_male  ET_NC  0.040800
# 7  -2.098527  Right_Cerebellum_White_Matter_dpa_age_male  ET_NC  0.035859
# 8   0.097782              Cerebellum_Cortex_dpa_age_male  ET_NC  0.680400
# 9   0.306526              Cerebellum_Cortex_dpa_age_male  ET_NC  0.759204
# 10 -0.419150        Cerebellum_White_Matter_dpa_age_male  ET_NC  0.086400
# 11 -1.792001        Cerebellum_White_Matter_dpa_age_male  ET_NC  0.073133
# 12  0.014127                      Vermis_VI_dpa_age_male  ET_NC  0.961600
# 13 -0.011789                      Vermis_VI_dpa_age_male  ET_NC  0.990594
# 14  0.035740                   Vermis_CrusI_dpa_age_male  ET_NC  0.907200
# 15  0.247579                   Vermis_CrusI_dpa_age_male  ET_NC  0.804460
# 16 -0.376579                  Vermis_CrusII_dpa_age_male  ET_NC  0.118800
# 17 -2.004212                  Vermis_CrusII_dpa_age_male  ET_NC  0.045047
# 18  0.520096                     Left_CrusI_dpa_age_male  ET_NC  0.028400
# 19  2.016001                     Left_CrusI_dpa_age_male  ET_NC  0.043800
# 20  0.327119                    Right_CrusI_dpa_age_male  ET_NC  0.186400
# 21  1.862738                    Right_CrusI_dpa_age_male  ET_NC  0.062499
# 22  0.167556                    Left_CrusII_dpa_age_male  ET_NC  0.501200
# 23  0.613053                    Left_CrusII_dpa_age_male  ET_NC  0.539841
# 24  0.057309                   Right_CrusII_dpa_age_male  ET_NC  0.836800
# 25  0.129684                   Right_CrusII_dpa_age_male  ET_NC  0.896816
# 26 -0.505860                   Left_Dentate_dpa_age_male  ET_NC  0.031200
# 27 -2.440422                   Left_Dentate_dpa_age_male  ET_NC  0.014670
# 28 -0.613873                  Right_Dentate_dpa_age_male  ET_NC  0.014000
# 29 -2.853054                  Right_Dentate_dpa_age_male  ET_NC  0.004330
# 30  0.261209                         MDTB_1_dpa_age_male  ET_NC  0.291200
# 31  0.813474                         MDTB_1_dpa_age_male  ET_NC  0.415946
# 32  0.291211                         MDTB_2_dpa_age_male  ET_NC  0.220000
# 33  1.143580                         MDTB_2_dpa_age_male  ET_NC  0.252798
# 34  0.263359                         MDTB_4_dpa_age_male  ET_NC  0.280800
# 35  0.978527                         MDTB_4_dpa_age_male  ET_NC  0.327814
# 36  0.373653                         MDTB_5_dpa_age_male  ET_NC  0.124400
# 37  1.084632                         MDTB_5_dpa_age_male  ET_NC  0.278085
#
#         test
# 0    Cohen_d
# 1   rank_sum
# 2    Cohen_d
# 3   rank_sum
# 4    Cohen_d
# 5   rank_sum
# 6    Cohen_d
# 7   rank_sum
# 8    Cohen_d
# 9   rank_sum
# 10   Cohen_d
# 11  rank_sum
# 12   Cohen_d
# 13  rank_sum
# 14   Cohen_d
# 15  rank_sum
# 16   Cohen_d
# 17  rank_sum
# 18   Cohen_d
# 19  rank_sum
# 20   Cohen_d
# 21  rank_sum
# 22   Cohen_d
# 23  rank_sum
# 24   Cohen_d
# 25  rank_sum
# 26   Cohen_d
# 27  rank_sum
# 28   Cohen_d
# 29  rank_sum
# 30   Cohen_d
# 31  rank_sum
# 32   Cohen_d
# 33  rank_sum
# 34   Cohen_d
# 35  rank_sum
# 36   Cohen_d
# 37  rank_sum

# %%
# Experiment 5: volumentry analysis for cerebellar gray and white matter for ET
dat_cere_gw, cere_gw_col = ctr_tiv(df, tar_list, 'InfraTentorialVol', ['age','male'], 'dpa')
res_cere_gw = cal_es(dat_cere_gw, cere_gw_col[int(len(cere_gw_col)/2):], alpha_, n_permu_, sts_tests_list, group_mni_list);

C_MAP='coolwarm_r'; VMIN=0; VMAX=0.1;
vis_df = res_cere_gw.copy()
vis_df['ROI']=vis_df['ROI'].map(lambda x: x[0:-9]);
es_df=vis_df[['ROI','test','ES']]; p_df=vis_df[['ROI','test','p_val']]
es_df = es_df.pivot("ROI", "test"); p_df = p_df.pivot("ROI", "test"); 
# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
ax1=sns.heatmap(p_df, annot=es_df, fmt=".4f", linewidths=.5, cmap=C_MAP, vmin=VMIN, vmax=VMAX, ax=ax)
ax1.set_title('ET and NC Cerebellum Volemetry after control age, sex and InfraTentorialVol with dpa')
display(res_cere_gw)
# Out:
# Using  dpa
# New columns 38 :  ['Left_Cerebellum_Cortex_dpa', 'Left_Cerebellum_White_Matter_dpa', 'Right_Cerebellum_Cortex_dpa', 'Right_Cerebellum_White_Matter_dpa', 'Cerebellum_Cortex_dpa', 'Cerebellum_White_Matter_dpa', 'Vermis_VI_dpa', 'Vermis_CrusI_dpa', 'Vermis_CrusII_dpa', 'Left_CrusI_dpa', 'Right_CrusI_dpa', 'Left_CrusII_dpa', 'Right_CrusII_dpa', 'Left_Dentate_dpa', 'Right_Dentate_dpa', 'MDTB_1_dpa', 'MDTB_2_dpa', 'MDTB_4_dpa', 'MDTB_5_dpa', 'Left_Cerebellum_Cortex_dpa_age_male', 'Left_Cerebellum_White_Matter_dpa_age_male', 'Right_Cerebellum_Cortex_dpa_age_male', 'Right_Cerebellum_White_Matter_dpa_age_male', 'Cerebellum_Cortex_dpa_age_male', 'Cerebellum_White_Matter_dpa_age_male', 'Vermis_VI_dpa_age_male', 'Vermis_CrusI_dpa_age_male', 'Vermis_CrusII_dpa_age_male', 'Left_CrusI_dpa_age_male', 'Right_CrusI_dpa_age_male', 'Left_CrusII_dpa_age_male', 'Right_CrusII_dpa_age_male', 'Left_Dentate_dpa_age_male', 'Right_Dentate_dpa_age_male', 'MDTB_1_dpa_age_male', 'MDTB_2_dpa_age_male', 'MDTB_4_dpa_age_male', 'MDTB_5_dpa_age_male']
#           ES                                         ROI  group     p_val  \
# 0  -0.719726         Left_Cerebellum_Cortex_dpa_age_male  ET_NC  0.002800
# 1  -3.336423         Left_Cerebellum_Cortex_dpa_age_male  ET_NC  0.000849
# 2  -0.850343   Left_Cerebellum_White_Matter_dpa_age_male  ET_NC  0.000800
# 3  -3.371791   Left_Cerebellum_White_Matter_dpa_age_male  ET_NC  0.000747
# 4  -0.827676        Right_Cerebellum_Cortex_dpa_age_male  ET_NC  0.000800
# 5  -3.477897        Right_Cerebellum_Cortex_dpa_age_male  ET_NC  0.000505
# 6  -0.970620  Right_Cerebellum_White_Matter_dpa_age_male  ET_NC  0.000000
# 7  -3.701897  Right_Cerebellum_White_Matter_dpa_age_male  ET_NC  0.000214
# 8  -0.779718              Cerebellum_Cortex_dpa_age_male  ET_NC  0.001600
# 9  -3.501476              Cerebellum_Cortex_dpa_age_male  ET_NC  0.000463
# 10 -0.918060        Cerebellum_White_Matter_dpa_age_male  ET_NC  0.000800
# 11 -3.525055        Cerebellum_White_Matter_dpa_age_male  ET_NC  0.000423
# 12 -0.795845                      Vermis_VI_dpa_age_male  ET_NC  0.001200
# 13 -3.041686                      Vermis_VI_dpa_age_male  ET_NC  0.002353
# 14 -0.404292                   Vermis_CrusI_dpa_age_male  ET_NC  0.105200
# 15 -1.945264                   Vermis_CrusI_dpa_age_male  ET_NC  0.051743
# 16 -1.057895                  Vermis_CrusII_dpa_age_male  ET_NC  0.000000
# 17 -3.925897                  Vermis_CrusII_dpa_age_male  ET_NC  0.000086
# 18 -0.512724                     Left_CrusI_dpa_age_male  ET_NC  0.035200
# 19 -2.275370                     Left_CrusI_dpa_age_male  ET_NC  0.022884
# 20 -0.568785                    Right_CrusI_dpa_age_male  ET_NC  0.018800
# 21 -2.228212                    Right_CrusI_dpa_age_male  ET_NC  0.025866
# 22 -0.643262                    Left_CrusII_dpa_age_male  ET_NC  0.007600
# 23 -2.970949                    Left_CrusII_dpa_age_male  ET_NC  0.002969
# 24 -0.709069                   Right_CrusII_dpa_age_male  ET_NC  0.004800
# 25 -3.265686                   Right_CrusII_dpa_age_male  ET_NC  0.001092
# 26 -1.060391                   Left_Dentate_dpa_age_male  ET_NC  0.000000
# 27 -3.996634                   Left_Dentate_dpa_age_male  ET_NC  0.000064
# 28 -1.163513                  Right_Dentate_dpa_age_male  ET_NC  0.000000
# 29 -4.314950                  Right_Dentate_dpa_age_male  ET_NC  0.000016
# 30 -0.752965                         MDTB_1_dpa_age_male  ET_NC  0.002400
# 31 -3.253897                         MDTB_1_dpa_age_male  ET_NC  0.001138
# 32 -0.730953                         MDTB_2_dpa_age_male  ET_NC  0.004000
# 33 -3.171370                         MDTB_2_dpa_age_male  ET_NC  0.001517
# 34 -0.635741                         MDTB_4_dpa_age_male  ET_NC  0.010000
# 35 -2.912002                         MDTB_4_dpa_age_male  ET_NC  0.003591
# 36 -0.593250                         MDTB_5_dpa_age_male  ET_NC  0.015200
# 37 -2.534738                         MDTB_5_dpa_age_male  ET_NC  0.011253
#
#         test
# 0    Cohen_d
# 1   rank_sum
# 2    Cohen_d
# 3   rank_sum
# 4    Cohen_d
# 5   rank_sum
# 6    Cohen_d
# 7   rank_sum
# 8    Cohen_d
# 9   rank_sum
# 10   Cohen_d
# 11  rank_sum
# 12   Cohen_d
# 13  rank_sum
# 14   Cohen_d
# 15  rank_sum
# 16   Cohen_d
# 17  rank_sum
# 18   Cohen_d
# 19  rank_sum
# 20   Cohen_d
# 21  rank_sum
# 22   Cohen_d
# 23  rank_sum
# 24   Cohen_d
# 25  rank_sum
# 26   Cohen_d
# 27  rank_sum
# 28   Cohen_d
# 29  rank_sum
# 30   Cohen_d
# 31  rank_sum
# 32   Cohen_d
# 33  rank_sum
# 34   Cohen_d
# 35  rank_sum
# 36   Cohen_d
# 37  rank_sum

# %%
tmp_df = df.copy() 
tmp_df['cerebellumVol']=tmp_df['Cerebellum_Cortex']+tmp_df['Cerebellum_White_Matter']
dat_cere_gw, cere_gw_col = ctr_tiv(tmp_df, tar_list, 'cerebellumVol', ['age','male'], 'rm_norm')
res_cere_gw = cal_es(dat_cere_gw, cere_gw_col, alpha_, n_permu_, sts_tests_list, group_mni_list);

C_MAP='coolwarm_r'; VMIN=0; VMAX=0.1;
vis_df = res_cere_gw.copy()
vis_df['ROI']=vis_df['ROI'].map(lambda x: x);
es_df=vis_df[['ROI','test','ES']]; p_df=vis_df[['ROI','test','p_val']]
es_df = es_df.pivot("ROI", "test"); p_df = p_df.pivot("ROI", "test"); 
# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
ax1=sns.heatmap(p_df, annot=es_df, fmt=".4f", linewidths=.5, cmap=C_MAP, vmin=VMIN, vmax=VMAX, ax=ax)
ax1.set_title('ET and NC Cerebellum Volemetry after control age, sex and cerebellumVol with rm_norm')
display(res_cere_gw)
# Out:
# Using  rm_norm
# New columns 19 :  ['Left_Cerebellum_Cortex_cerebellumVol_age_male', 'Left_Cerebellum_White_Matter_cerebellumVol_age_male', 'Right_Cerebellum_Cortex_cerebellumVol_age_male', 'Right_Cerebellum_White_Matter_cerebellumVol_age_male', 'Cerebellum_Cortex_cerebellumVol_age_male', 'Cerebellum_White_Matter_cerebellumVol_age_male', 'Vermis_VI_cerebellumVol_age_male', 'Vermis_CrusI_cerebellumVol_age_male', 'Vermis_CrusII_cerebellumVol_age_male', 'Left_CrusI_cerebellumVol_age_male', 'Right_CrusI_cerebellumVol_age_male', 'Left_CrusII_cerebellumVol_age_male', 'Right_CrusII_cerebellumVol_age_male', 'Left_Dentate_cerebellumVol_age_male', 'Right_Dentate_cerebellumVol_age_male', 'MDTB_1_cerebellumVol_age_male', 'MDTB_2_cerebellumVol_age_male', 'MDTB_4_cerebellumVol_age_male', 'MDTB_5_cerebellumVol_age_male']
#           ES                                                ROI  group  \
# 0   0.901635      Left_Cerebellum_Cortex_cerebellumVol_age_male  ET_NC
# 1   3.501476      Left_Cerebellum_Cortex_cerebellumVol_age_male  ET_NC
# 2  -0.459112  Left_Cerebellum_White_Matter_cerebellumVol_age...  ET_NC
# 3  -1.792001  Left_Cerebellum_White_Matter_cerebellumVol_age...  ET_NC
# 4   0.208964     Right_Cerebellum_Cortex_cerebellumVol_age_male  ET_NC
# 5   1.202527     Right_Cerebellum_Cortex_cerebellumVol_age_male  ET_NC
# 6  -0.730304  Right_Cerebellum_White_Matter_cerebellumVol_ag...  ET_NC
# 7  -2.652633  Right_Cerebellum_White_Matter_cerebellumVol_ag...  ET_NC
# 8   0.634272           Cerebellum_Cortex_cerebellumVol_age_male  ET_NC
# 9   2.464001           Cerebellum_Cortex_cerebellumVol_age_male  ET_NC
# 10 -0.634272     Cerebellum_White_Matter_cerebellumVol_age_male  ET_NC
# 11 -2.464001     Cerebellum_White_Matter_cerebellumVol_age_male  ET_NC
# 12  0.238406                   Vermis_VI_cerebellumVol_age_male  ET_NC
# 13  1.155369                   Vermis_VI_cerebellumVol_age_male  ET_NC
# 14  0.120178                Vermis_CrusI_cerebellumVol_age_male  ET_NC
# 15  0.506948                Vermis_CrusI_cerebellumVol_age_male  ET_NC
# 16 -0.269672               Vermis_CrusII_cerebellumVol_age_male  ET_NC
# 17 -1.473685               Vermis_CrusII_cerebellumVol_age_male  ET_NC
# 18  0.802236                  Left_CrusI_cerebellumVol_age_male  ET_NC
# 19  2.876633                  Left_CrusI_cerebellumVol_age_male  ET_NC
# 20  0.604668                 Right_CrusI_cerebellumVol_age_male  ET_NC
# 21  2.534738                 Right_CrusI_cerebellumVol_age_male  ET_NC
# 22  0.497889                 Left_CrusII_cerebellumVol_age_male  ET_NC
# 23  1.980633                 Left_CrusII_cerebellumVol_age_male  ET_NC
# 24  0.312073                Right_CrusII_cerebellumVol_age_male  ET_NC
# 25  2.016001                Right_CrusII_cerebellumVol_age_male  ET_NC
# 26 -0.270895                Left_Dentate_cerebellumVol_age_male  ET_NC
# 27 -1.721264                Left_Dentate_cerebellumVol_age_male  ET_NC
# 28 -0.399720               Right_Dentate_cerebellumVol_age_male  ET_NC
# 29 -2.298949               Right_Dentate_cerebellumVol_age_male  ET_NC
# 30  0.627370                      MDTB_1_cerebellumVol_age_male  ET_NC
# 31  2.534738                      MDTB_1_cerebellumVol_age_male  ET_NC
# 32  0.665835                      MDTB_2_cerebellumVol_age_male  ET_NC
# 33  2.676212                      MDTB_2_cerebellumVol_age_male  ET_NC
# 34  0.676741                      MDTB_4_cerebellumVol_age_male  ET_NC
# 35  2.440422                      MDTB_4_cerebellumVol_age_male  ET_NC
# 36  0.766880                      MDTB_5_cerebellumVol_age_male  ET_NC
# 37  2.841265                      MDTB_5_cerebellumVol_age_male  ET_NC
#
#        p_val      test
# 0   0.000400   Cohen_d
# 1   0.000463  rank_sum
# 2   0.059600   Cohen_d
# 3   0.073133  rank_sum
# 4   0.396000   Cohen_d
# 5   0.229159  rank_sum
# 6   0.002800   Cohen_d
# 7   0.007987  rank_sum
# 8   0.006800   Cohen_d
# 9   0.013740  rank_sum
# 10  0.008400   Cohen_d
# 11  0.013740  rank_sum
# 12  0.307200   Cohen_d
# 13  0.247939  rank_sum
# 14  0.639600   Cohen_d
# 15  0.612192  rank_sum
# 16  0.269600   Cohen_d
# 17  0.140566  rank_sum
# 18  0.001200   Cohen_d
# 19  0.004019  rank_sum
# 20  0.014000   Cohen_d
# 21  0.011253  rank_sum
# 22  0.044400   Cohen_d
# 23  0.047632  rank_sum
# 24  0.196400   Cohen_d
# 25  0.043800  rank_sum
# 26  0.266400   Cohen_d
# 27  0.085203  rank_sum
# 28  0.104800   Cohen_d
# 29  0.021508  rank_sum
# 30  0.012000   Cohen_d
# 31  0.011253  rank_sum
# 32  0.006400   Cohen_d
# 33  0.007446  rank_sum
# 34  0.009200   Cohen_d
# 35  0.014670  rank_sum
# 36  0.002800   Cohen_d
# 37  0.004493  rank_sum

# %%
tmp_df = df.copy() 
tmp_df['cerebellumVol']=tmp_df['Cerebellum_Cortex']+tmp_df['Cerebellum_White_Matter']
dat_cere_gw, cere_gw_col = ctr_tiv(tmp_df, tar_list, 'cerebellumVol', ['age','male'], 'dpa')
res_cere_gw = cal_es(dat_cere_gw, cere_gw_col[int(len(cere_gw_col)/2):], alpha_, n_permu_, sts_tests_list, group_mni_list);

C_MAP='coolwarm_r'; VMIN=0; VMAX=0.1;
vis_df = res_cere_gw.copy()
vis_df['ROI']=vis_df['ROI'].map(lambda x: x);
es_df=vis_df[['ROI','test','ES']]; p_df=vis_df[['ROI','test','p_val']]
es_df = es_df.pivot("ROI", "test"); p_df = p_df.pivot("ROI", "test"); 
# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
ax1=sns.heatmap(p_df, annot=es_df, fmt=".4f", linewidths=.5, cmap=C_MAP, vmin=VMIN, vmax=VMAX, ax=ax)
ax1.set_title('ET and NC Cerebellum Volemetry after control age, sex and cerebellumVol with dpa')
display(res_cere_gw)
# Out:
# Using  dpa
# New columns 38 :  ['Left_Cerebellum_Cortex_dpa', 'Left_Cerebellum_White_Matter_dpa', 'Right_Cerebellum_Cortex_dpa', 'Right_Cerebellum_White_Matter_dpa', 'Cerebellum_Cortex_dpa', 'Cerebellum_White_Matter_dpa', 'Vermis_VI_dpa', 'Vermis_CrusI_dpa', 'Vermis_CrusII_dpa', 'Left_CrusI_dpa', 'Right_CrusI_dpa', 'Left_CrusII_dpa', 'Right_CrusII_dpa', 'Left_Dentate_dpa', 'Right_Dentate_dpa', 'MDTB_1_dpa', 'MDTB_2_dpa', 'MDTB_4_dpa', 'MDTB_5_dpa', 'Left_Cerebellum_Cortex_dpa_age_male', 'Left_Cerebellum_White_Matter_dpa_age_male', 'Right_Cerebellum_Cortex_dpa_age_male', 'Right_Cerebellum_White_Matter_dpa_age_male', 'Cerebellum_Cortex_dpa_age_male', 'Cerebellum_White_Matter_dpa_age_male', 'Vermis_VI_dpa_age_male', 'Vermis_CrusI_dpa_age_male', 'Vermis_CrusII_dpa_age_male', 'Left_CrusI_dpa_age_male', 'Right_CrusI_dpa_age_male', 'Left_CrusII_dpa_age_male', 'Right_CrusII_dpa_age_male', 'Left_Dentate_dpa_age_male', 'Right_Dentate_dpa_age_male', 'MDTB_1_dpa_age_male', 'MDTB_2_dpa_age_male', 'MDTB_4_dpa_age_male', 'MDTB_5_dpa_age_male']
#           ES                                         ROI  group     p_val  \
# 0   0.855870         Left_Cerebellum_Cortex_dpa_age_male  ET_NC  0.000800
# 1   3.418949         Left_Cerebellum_Cortex_dpa_age_male  ET_NC  0.000629
# 2  -0.468198   Left_Cerebellum_White_Matter_dpa_age_male  ET_NC  0.058800
# 3  -1.874527   Left_Cerebellum_White_Matter_dpa_age_male  ET_NC  0.060858
# 4   0.253555        Right_Cerebellum_Cortex_dpa_age_male  ET_NC  0.307600
# 5   1.355790        Right_Cerebellum_Cortex_dpa_age_male  ET_NC  0.175166
# 6  -0.728639  Right_Cerebellum_White_Matter_dpa_age_male  ET_NC  0.002800
# 7  -2.664423  Right_Cerebellum_White_Matter_dpa_age_male  ET_NC  0.007712
# 8   0.634800              Cerebellum_Cortex_dpa_age_male  ET_NC  0.007200
# 9   2.440422              Cerebellum_Cortex_dpa_age_male  ET_NC  0.014670
# 10 -0.634800        Cerebellum_White_Matter_dpa_age_male  ET_NC  0.010400
# 11 -2.440422        Cerebellum_White_Matter_dpa_age_male  ET_NC  0.014670
# 12  0.046395                      Vermis_VI_dpa_age_male  ET_NC  0.851200
# 13  0.471579                      Vermis_VI_dpa_age_male  ET_NC  0.637227
# 14  0.030764                   Vermis_CrusI_dpa_age_male  ET_NC  0.915600
# 15  0.377263                   Vermis_CrusI_dpa_age_male  ET_NC  0.705978
# 16 -0.367638                  Vermis_CrusII_dpa_age_male  ET_NC  0.136000
# 17 -2.086738                  Vermis_CrusII_dpa_age_male  ET_NC  0.036912
# 18  0.691909                     Left_CrusI_dpa_age_male  ET_NC  0.006400
# 19  2.711580                     Left_CrusI_dpa_age_male  ET_NC  0.006696
# 20  0.523259                    Right_CrusI_dpa_age_male  ET_NC  0.036800
# 21  2.110317                    Right_CrusI_dpa_age_male  ET_NC  0.034831
# 22  0.334626                    Left_CrusII_dpa_age_male  ET_NC  0.166000
# 23  1.438317                    Left_CrusII_dpa_age_male  ET_NC  0.150344
# 24  0.122621                   Right_CrusII_dpa_age_male  ET_NC  0.626400
# 25  0.377263                   Right_CrusII_dpa_age_male  ET_NC  0.705978
# 26 -0.337732                   Left_Dentate_dpa_age_male  ET_NC  0.159200
# 27 -2.240001                   Left_Dentate_dpa_age_male  ET_NC  0.025091
# 28 -0.432418                  Right_Dentate_dpa_age_male  ET_NC  0.081600
# 29 -2.499370                  Right_Dentate_dpa_age_male  ET_NC  0.012441
# 30  0.415920                         MDTB_1_dpa_age_male  ET_NC  0.086800
# 31  1.591580                         MDTB_1_dpa_age_male  ET_NC  0.111479
# 32  0.524537                         MDTB_2_dpa_age_male  ET_NC  0.032400
# 33  1.992422                         MDTB_2_dpa_age_male  ET_NC  0.046325
# 34  0.514919                         MDTB_4_dpa_age_male  ET_NC  0.036400
# 35  1.898106                         MDTB_4_dpa_age_male  ET_NC  0.057682
# 36  0.587307                         MDTB_5_dpa_age_male  ET_NC  0.018000
# 37  2.181054                         MDTB_5_dpa_age_male  ET_NC  0.029179
#
#         test
# 0    Cohen_d
# 1   rank_sum
# 2    Cohen_d
# 3   rank_sum
# 4    Cohen_d
# 5   rank_sum
# 6    Cohen_d
# 7   rank_sum
# 8    Cohen_d
# 9   rank_sum
# 10   Cohen_d
# 11  rank_sum
# 12   Cohen_d
# 13  rank_sum
# 14   Cohen_d
# 15  rank_sum
# 16   Cohen_d
# 17  rank_sum
# 18   Cohen_d
# 19  rank_sum
# 20   Cohen_d
# 21  rank_sum
# 22   Cohen_d
# 23  rank_sum
# 24   Cohen_d
# 25  rank_sum
# 26   Cohen_d
# 27  rank_sum
# 28   Cohen_d
# 29  rank_sum
# 30   Cohen_d
# 31  rank_sum
# 32   Cohen_d
# 33  rank_sum
# 34   Cohen_d
# 35  rank_sum
# 36   Cohen_d
# 37  rank_sum

# %%
# GLM Model 
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.formula.api import glm
import statsmodels.stats as sts

# basic GLM
covariate_model_str = '~age+sex+InfraTentorialVol+C(group, Treatment(reference="NC"))';
#covariate_dict = glm_test(sts_df, tar_list, covariate_model_str);
#covariate_df   = sts_test(tar_list, sts_df, stats_cols, alpha, n_permu, 'covariate')
df = curr_df[(curr_df['group']=='ET')|(curr_df['group']=='NC')]

dat, new_col = ctr_tiv(df, cerebellum_list, 'eTIV', ['age','male'], 'asm')
