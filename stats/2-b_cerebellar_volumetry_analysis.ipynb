# %% [markdown]
# # Volumetry Analysis
# ## Data:
#     - 1. Freesurfer results: ICV. Lh/Rh_cerebellum_gm/wm (generated by "collect_volumes.sh" script);
#         - Left/ Right cerebellum gray/white matter volumes
#     - 2. Cerebellar SUIT segmentation with SUIT and MDTB atlas;
#          - SUIT: Vermis VI, Vermis_CrusI,  Vermis_CrusII, CrusI, CrusII, Dentate nucleus;
#          - MBTB: MDTB functional regions 1,2,4,5;
#     - 3. Cerebellar MAGeTBrain [MAGeTBrain pipeline](https://github.com/CobraLab/documentation/wiki/MAGeTBrain#collecting-volumes)
#         - MAGeT: Vermis VI, Vermis_CrusI,  Vermis_CrusII, CrusI, CrusII, Dentate nucleus;
#
# ## Cohorts
# - Current cohort: MNI ET/NC (38/32), QC not included.
#
# ## Tasks
# - Compare total cerebellar volumes (left and right)
# - Compare lobule volumes (13 per hemisphere)
#
# ## Covariates
# - Age, Sex, site, eTIV

# %%
## read demographic data and freesurfer outputs
from pathlib import Path
import nipype.interfaces.io as nio
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data_dir = Path("/codes/tab_data")
mni_file  = data_dir/'MNI_Des-cere_preped.csv'
adni_ppmi_file = data_dir/'ADNI-PPMI_Des-cere_preped.csv'

mni_df       = pd.read_csv(mni_file , sep=',', header=0, index_col=0);
adni_ppmi_df = pd.read_csv(adni_ppmi_file , sep=',', header=0, index_col=0);

#excluding list
data_df = pd.concat([mni_df, adni_ppmi_df])
drop_col_list = ['Left_WM_hypointensities', 'Right_WM_hypointensities', '5th_Ventricle'];
data_df=data_df.drop(columns=drop_col_list);
# Out:
# 211008-06:12:49,383 nipype.utils WARNING:
# 	 A newer version (1.5.1) of nipy/nipype is available. You are using 1.5.0

# %%
# prepare data for this script
SUIT_labels = ['Left_I_IV','Right_I_IV','Left_V','Right_V','Left_VI','Vermis_VI','Right_VI','Left_CrusI','Vermis_CrusI','Right_CrusI','Left_CrusII','Vermis_CrusII','Right_CrusII','Left_VIIb','Vermis_VIIb','Right_VIIb','Left_VIIIa','Vermis_VIIIa','Right_VIIIa','Left_VIIIb','Vermis_VIIIb','Right_VIIIb','Left_IX','Vermis_IX','Right_IX','Left_X','Vermis_X','Right_X','Left_Dentate','Right_Dentate','Left_Interposed','Right_Interposed','Left_Fastigial','Right_Fastigial'];
SUIT_labels = [ x.replace('-','_') for x in SUIT_labels]
SUIT_l_labels = ['Left_I_IV',  'Left_V', 'Left_VI', 'Left_CrusI', 'Left_CrusII', 'Left_VIIb', 'Left_VIIIa', 'Left_VIIIb', 'Left_IX', 'Left_X', 'Left_Dentate', 'Left_Interposed', 'Left_Fastigial'];
SUIT_r_labels = ['Right_I_IV','Right_V','Right_VI','Right_CrusI','Right_CrusII','Right_VIIb','Right_VIIIa','Right_VIIIb','Right_IX','Right_X','Right_Dentate','Right_Interposed','Right_Fastigial'];
SUIT_v_labels = ['Vermis_VI', 'Vermis_CrusI', 'Vermis_CrusII', 'Vermis_VIIb', 'Vermis_VIIIa','Vermis_VIIIb', 'Vermis_IX', 'Vermis_X'];
MDTB_labels   = ['MDTB_'+str(x+1) for x in range(10)];
analysis_list = ['age','sex','group','site','eTIV','SupraTentorialVol', 'SupraTentorialVolNotVent',
                 'Left_Cerebellum_White_Matter','Left_Cerebellum_Cortex','Right_Cerebellum_White_Matter','Right_Cerebellum_Cortex']+SUIT_l_labels+SUIT_r_labels+SUIT_v_labels+MDTB_labels
curr_df = data_df.loc[:,analysis_list]
curr_df.loc[:,'Cerebellum_White_Matter']=curr_df['Left_Cerebellum_White_Matter']+curr_df['Right_Cerebellum_White_Matter'];
curr_df.loc[:,'Cerebellum_Cortex']=curr_df['Left_Cerebellum_Cortex']+curr_df['Right_Cerebellum_Cortex'];
curr_df.loc[:,'cerebellumVol']=curr_df['Cerebellum_Cortex']+curr_df['Cerebellum_White_Matter']
# calculate the Infra tentorial volumen approximately by eTIV-SupraTentorialVol
curr_df.loc[:,'InfraTentorialVol']=curr_df['eTIV']-curr_df['SupraTentorialVol']
curr_df.loc[:,'male']=[int(x=='M') for x in curr_df['sex']]

# %%
### statistical analysis
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from utils_et_biomarker.utils import ctr_tiv, glm_test, rep_model, ctr_by_nc, cal_es,creat_Bonf_df

# get the MNI dataset for ET/NC analysis
df = curr_df[(curr_df['group']=='ET')|(curr_df['group']=='NC')].copy()

# get all 3 datasets for ET/NC analysis
df_all=curr_df.copy()
df_all.loc[:,'is_mni'] =[1 if int(x=='ET' or x=='NC') else 0 for x in df_all['group']]
df_all.loc[:,'is_ppmi']=[int(x=='PPMI') for x in df_all['group']]
df_all.loc[:,'is_adni']=[int(x=='ADNI') for x in df_all['group']]
df_all.loc[:,'group']  =[x if x=='ET' else 'NC' for x in df_all['group']]

# get indicator variable
alpha_=5; n_permu_=5000;

## covariates and target labels
info_list=['age','sex','group','site','eTIV','SupraTentorialVol', 'SupraTentorialVolNotVent','InfraTentorialVol']
cerebellum_list = ['Left_Cerebellum_Cortex','Left_Cerebellum_White_Matter',
                   'Right_Cerebellum_Cortex','Right_Cerebellum_White_Matter',
                   'Cerebellum_Cortex','Cerebellum_White_Matter'];
lobular_list = ['Vermis_VI', 'Vermis_CrusI', 'Vermis_CrusII', 
                'Left_CrusI', 'Right_CrusI', 'Left_CrusII', 'Right_CrusII','Left_Dentate', 'Right_Dentate',
                'MDTB_1', 'MDTB_2', 'MDTB_4', 'MDTB_5'];
tar_list = cerebellum_list+lobular_list;

df_n_comp=pd.DataFrame(zip(cerebellum_list+lobular_list, [4,4,4,4,2,2, 9,9,9,9,9,9,9,9,9, 4,4,4,4]), 
                       index=cerebellum_list+lobular_list, columns=['ROI','n_comp'])
sts_tests_list = ['Cohen_d', 'rank_sum']; 
group_mni_list = ['ET','NC'];

# %% [markdown]
# ## Cerebellar volumentry for MNI ET/NC (38/32) dataset
#     1. Experiment 1: without controling for any covariates;
#     2. Experiment 2: control age/sex/eTIV with rm control group method;
#     3. Experiment 3: control age/sex/infratentorialVolume with rm control group method;
#     4. Experiment 4: control age/sex/eTIV with direct proportion adjustment method;
#     5. Experiment 5: control age/sex/infratentorialVolume with direct proportion adjustment method;
#     6. Experiment 6: control age/sex/cerebellumVol with rm control group method;
#     7. Experiment 7: control age/sex/cerebellumVol with direct proportion adjustment method;

# %%
# Experiment 1: without controling for any covariates;
res_cere_gw = cal_es(df, tar_list, alpha_, n_permu_, sts_tests_list, group_mni_list, "");
# Experiment 2: control age/sex/eTIV with rm control group method;
dat_cere_gw_1, cere_gw_col_1 = ctr_tiv(df, tar_list, 'eTIV', ['age','male'], 'rm_norm')
res_cere_gw_1 = cal_es(dat_cere_gw_1, cere_gw_col_1, alpha_, n_permu_, sts_tests_list, group_mni_list,"RN with A,S,TIV");
res_cere_gw_1['ROI']=res_cere_gw_1['ROI'].map(lambda x: x[0:-14]);
# Experiment 3: control age/sex/infratentorialVolume with rm control group method;
dat_cere_gw_2, cere_gw_col_2 = ctr_tiv(df, tar_list, 'InfraTentorialVol', ['age','male'], 'rm_norm')
res_cere_gw_2 = cal_es(dat_cere_gw_2, cere_gw_col_2, alpha_, n_permu_, sts_tests_list, group_mni_list,"RN with A,S,infTV");
res_cere_gw_2['ROI']=res_cere_gw_2['ROI'].map(lambda x: x[0:-27]);
#Experiment 4: control age/sex/eTIV with direct proportion adjustment method;
dat_cere_gw_3, cere_gw_col_3 = ctr_tiv(df, tar_list, 'eTIV', ['age','male'], 'dpa')
res_cere_gw_3 = cal_es(dat_cere_gw_3, cere_gw_col_3, alpha_, n_permu_, sts_tests_list, group_mni_list,"DPA with A,S,TIV");
res_cere_gw_3['ROI']=res_cere_gw_3['ROI'].map(lambda x: x[0:-13])
#Experiment 5: control age/sex/infratentorialVolume with direct proportion adjustment method;
dat_cere_gw_4, cere_gw_col_4 = ctr_tiv(df, tar_list, 'InfraTentorialVol', ['age','male'], 'dpa')
res_cere_gw_4 = cal_es(dat_cere_gw_4, cere_gw_col_4, alpha_, n_permu_, sts_tests_list, group_mni_list,"DPA with A,S,infTV");
res_cere_gw_4['ROI']=res_cere_gw_4['ROI'].map(lambda x: x[0:-13]);
#Experiment 6: control age/sex/cerebellumVol with rm control group method;
dat_cere_gw_5, cere_gw_col_5 = ctr_tiv(df, tar_list, 'cerebellumVol', ['age','male'], 'rm_norm')
res_cere_gw_5 = cal_es(dat_cere_gw_5, cere_gw_col_5, alpha_, n_permu_, sts_tests_list, group_mni_list,"RN with A,S,Cere");
res_cere_gw_5['ROI']=res_cere_gw_5['ROI'].map(lambda x: x[0:-23]);
#Experiment 7: control age/sex/cerebellumVol with direct proportion adjustment method;
dat_cere_gw_6, cere_gw_col_6 = ctr_tiv(df, tar_list, 'cerebellumVol', ['age','male'], 'dpa')
res_cere_gw_6 = cal_es(dat_cere_gw_6, cere_gw_col_6, alpha_, n_permu_, sts_tests_list, group_mni_list,"DPA with A,S,Cere");
res_cere_gw_6['ROI']=res_cere_gw_6['ROI'].map(lambda x: x[0:-13]);
res_method_df=pd.concat([res_cere_gw, res_cere_gw_1, res_cere_gw_2, res_cere_gw_5, res_cere_gw_3, res_cere_gw_4, res_cere_gw_6])
# Out:
# Using  rm_norm
# New columns 19 :  ['Left_Cerebellum_Cortex_eTIV_age_male', 'Left_Cerebellum_White_Matter_eTIV_age_male', 'Right_Cerebellum_Cortex_eTIV_age_male', 'Right_Cerebellum_White_Matter_eTIV_age_male', 'Cerebellum_Cortex_eTIV_age_male', 'Cerebellum_White_Matter_eTIV_age_male', 'Vermis_VI_eTIV_age_male', 'Vermis_CrusI_eTIV_age_male', 'Vermis_CrusII_eTIV_age_male', 'Left_CrusI_eTIV_age_male', 'Right_CrusI_eTIV_age_male', 'Left_CrusII_eTIV_age_male', 'Right_CrusII_eTIV_age_male', 'Left_Dentate_eTIV_age_male', 'Right_Dentate_eTIV_age_male', 'MDTB_1_eTIV_age_male', 'MDTB_2_eTIV_age_male', 'MDTB_4_eTIV_age_male', 'MDTB_5_eTIV_age_male']
# Using  rm_norm
# New columns 19 :  ['Left_Cerebellum_Cortex_InfraTentorialVol_age_male', 'Left_Cerebellum_White_Matter_InfraTentorialVol_age_male', 'Right_Cerebellum_Cortex_InfraTentorialVol_age_male', 'Right_Cerebellum_White_Matter_InfraTentorialVol_age_male', 'Cerebellum_Cortex_InfraTentorialVol_age_male', 'Cerebellum_White_Matter_InfraTentorialVol_age_male', 'Vermis_VI_InfraTentorialVol_age_male', 'Vermis_CrusI_InfraTentorialVol_age_male', 'Vermis_CrusII_InfraTentorialVol_age_male', 'Left_CrusI_InfraTentorialVol_age_male', 'Right_CrusI_InfraTentorialVol_age_male', 'Left_CrusII_InfraTentorialVol_age_male', 'Right_CrusII_InfraTentorialVol_age_male', 'Left_Dentate_InfraTentorialVol_age_male', 'Right_Dentate_InfraTentorialVol_age_male', 'MDTB_1_InfraTentorialVol_age_male', 'MDTB_2_InfraTentorialVol_age_male', 'MDTB_4_InfraTentorialVol_age_male', 'MDTB_5_InfraTentorialVol_age_male']
# Using  dpa
# New columns 19 :  ['Left_Cerebellum_Cortex_dpa_age_male', 'Left_Cerebellum_White_Matter_dpa_age_male', 'Right_Cerebellum_Cortex_dpa_age_male', 'Right_Cerebellum_White_Matter_dpa_age_male', 'Cerebellum_Cortex_dpa_age_male', 'Cerebellum_White_Matter_dpa_age_male', 'Vermis_VI_dpa_age_male', 'Vermis_CrusI_dpa_age_male', 'Vermis_CrusII_dpa_age_male', 'Left_CrusI_dpa_age_male', 'Right_CrusI_dpa_age_male', 'Left_CrusII_dpa_age_male', 'Right_CrusII_dpa_age_male', 'Left_Dentate_dpa_age_male', 'Right_Dentate_dpa_age_male', 'MDTB_1_dpa_age_male', 'MDTB_2_dpa_age_male', 'MDTB_4_dpa_age_male', 'MDTB_5_dpa_age_male']
# Using  dpa
# New columns 19 :  ['Left_Cerebellum_Cortex_dpa_age_male', 'Left_Cerebellum_White_Matter_dpa_age_male', 'Right_Cerebellum_Cortex_dpa_age_male', 'Right_Cerebellum_White_Matter_dpa_age_male', 'Cerebellum_Cortex_dpa_age_male', 'Cerebellum_White_Matter_dpa_age_male', 'Vermis_VI_dpa_age_male', 'Vermis_CrusI_dpa_age_male', 'Vermis_CrusII_dpa_age_male', 'Left_CrusI_dpa_age_male', 'Right_CrusI_dpa_age_male', 'Left_CrusII_dpa_age_male', 'Right_CrusII_dpa_age_male', 'Left_Dentate_dpa_age_male', 'Right_Dentate_dpa_age_male', 'MDTB_1_dpa_age_male', 'MDTB_2_dpa_age_male', 'MDTB_4_dpa_age_male', 'MDTB_5_dpa_age_male']
# Using  rm_norm
# New columns 19 :  ['Left_Cerebellum_Cortex_cerebellumVol_age_male', 'Left_Cerebellum_White_Matter_cerebellumVol_age_male', 'Right_Cerebellum_Cortex_cerebellumVol_age_male', 'Right_Cerebellum_White_Matter_cerebellumVol_age_male', 'Cerebellum_Cortex_cerebellumVol_age_male', 'Cerebellum_White_Matter_cerebellumVol_age_male', 'Vermis_VI_cerebellumVol_age_male', 'Vermis_CrusI_cerebellumVol_age_male', 'Vermis_CrusII_cerebellumVol_age_male', 'Left_CrusI_cerebellumVol_age_male', 'Right_CrusI_cerebellumVol_age_male', 'Left_CrusII_cerebellumVol_age_male', 'Right_CrusII_cerebellumVol_age_male', 'Left_Dentate_cerebellumVol_age_male', 'Right_Dentate_cerebellumVol_age_male', 'MDTB_1_cerebellumVol_age_male', 'MDTB_2_cerebellumVol_age_male', 'MDTB_4_cerebellumVol_age_male', 'MDTB_5_cerebellumVol_age_male']
# Using  dpa
# New columns 19 :  ['Left_Cerebellum_Cortex_dpa_age_male', 'Left_Cerebellum_White_Matter_dpa_age_male', 'Right_Cerebellum_Cortex_dpa_age_male', 'Right_Cerebellum_White_Matter_dpa_age_male', 'Cerebellum_Cortex_dpa_age_male', 'Cerebellum_White_Matter_dpa_age_male', 'Vermis_VI_dpa_age_male', 'Vermis_CrusI_dpa_age_male', 'Vermis_CrusII_dpa_age_male', 'Left_CrusI_dpa_age_male', 'Right_CrusI_dpa_age_male', 'Left_CrusII_dpa_age_male', 'Right_CrusII_dpa_age_male', 'Left_Dentate_dpa_age_male', 'Right_Dentate_dpa_age_male', 'MDTB_1_dpa_age_male', 'MDTB_2_dpa_age_male', 'MDTB_4_dpa_age_male', 'MDTB_5_dpa_age_male']

# %%
# Vis for methods sensitivity analysis.
C_MAP='coolwarm_r'; VMIN=0; VMAX=0.1;
order_list=['Cohen_d','Cohen_d_RN with A,S,TIV','Cohen_d_RN with A,S,infTV', 'Cohen_d_RN with A,S,Cere',  
             'Cohen_d_DPA with A,S,TIV', 'Cohen_d_DPA with A,S,infTV', 'Cohen_d_RN with A,S,Cere', 
             'rank_sum', 'rank_sum_RN with A,S,TIV', 'rank_sum_RN with A,S,infTV', 'rank_sum_RN with A,S,Cere',
             'rank_sum_DPA with A,S,TIV', 'rank_sum_DPA with A,S,infTV', 'rank_sum_DPA with A,S,Cere']

vis_df = res_method_df.copy()
es_df=vis_df[['ROI','test','ES']]; p_df=vis_df[['ROI','test','p_val']]
es_df = es_df.pivot("ROI", "test"); p_df = p_df.pivot("ROI", "test"); 

# reorder columns
es_df_=es_df[pd.MultiIndex.from_tuples([('ES', x) for x in order_list], names=[None, 'test'])]
p_df_ = p_df[pd.MultiIndex.from_tuples([('p_val', x) for x in order_list], names=[None, 'test'])]

# create multiple comparison mask
pass_df, mask_df=creat_Bonf_df(p_df_, 0.05, df_n_comp)
anno_df =pd.DataFrame(np.array(es_df_))*pd.DataFrame(np.array(1-mask_df));
# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(30, 9))
ax1=sns.heatmap(p_df_, annot=anno_df, fmt=".4f", mask=mask_df,
                linewidths=.5, cmap=C_MAP, vmin=VMIN, vmax=VMAX, ax=ax)
ax1.set_title('Metods sensitivity analysis for ET and NC Cerebellum Volemetry comparison for MNI cohort (survive the Bonf. correction)')
f, ax = plt.subplots(figsize=(30, 9))
ax2=sns.heatmap(p_df_, annot=es_df_, fmt=".4f",
                linewidths=.5, cmap=C_MAP, vmin=VMIN, vmax=VMAX, ax=ax)
ax2.set_title('Metods sensitivity analysis for ET and NC Cerebellum Volemetry comparison for MNI cohort (full inform)')
# Out:
# Text(0.5, 1.0, 'Metods sensitivity analysis for ET and NC Cerebellum Volemetry comparison for MNI cohort (full inform)')

# %% [markdown]
# ## Cerebellar volumentry for all 3 datasets ET/NC(38/32+116+308)
#     1. Experiment 1: without controling for any covariates;
#     2. Experiment 2: control age/sex/eTIV with rm control group method;
#     3. Experiment 3: control age/sex/infratentorialVolume with rm control group method;
#     4. Experiment 4: control age/sex/eTIV with direct proportion adjustment method;
#     5. Experiment 5: control age/sex/infratentorialVolume with direct proportion adjustment method;
#     6. Experiment 6: control age/sex/cerebellumVol with rm control group method;
#     7. Experiment 7: control age/sex/cerebellumVol with direct proportion adjustment method;

# %%
# Experiment 1: without controling for any covariates;
res_cere_gw_all = cal_es(df_all, tar_list, alpha_, n_permu_, sts_tests_list, group_mni_list, "");
# Experiment 2: control age/sex/eTIV with rm control group method;
dat_cere_gw_all_1, cere_gw_all_col_1 = ctr_tiv(df_all, tar_list, 'eTIV', ['age','male', 'is_mni','is_ppmi','is_adni'], 'rm_norm')
res_cere_gw_all_1 = cal_es(dat_cere_gw_all_1, cere_gw_all_col_1, alpha_, n_permu_, sts_tests_list, group_mni_list,"RN with A,S,TIV");
res_cere_gw_all_1['ROI']=res_cere_gw_all_1['ROI'].map(lambda x: x[0:-37]);
# Experiment 3: control age/sex/infratentorialVolume with rm control group method;
dat_cere_gw_all_2, cere_gw_col_all_2 = ctr_tiv(df_all, tar_list, 'InfraTentorialVol', ['age','male', 'is_mni','is_ppmi','is_adni'], 'rm_norm')
res_cere_gw_all_2 = cal_es(dat_cere_gw_all_2, cere_gw_col_all_2, alpha_, n_permu_, sts_tests_list, group_mni_list,"RN with A,S,infTV");
res_cere_gw_all_2['ROI']=res_cere_gw_all_2['ROI'].map(lambda x: x[0:-50]);
#Experiment 4: control age/sex/eTIV with direct proportion adjustment method;
dat_cere_gw_all_3, cere_gw_all_col_3 = ctr_tiv(df_all, tar_list, 'eTIV', ['age','male', 'is_mni','is_ppmi','is_adni'], 'dpa')
res_cere_gw_all_3 = cal_es(dat_cere_gw_all_3, cere_gw_all_col_3, alpha_, n_permu_, sts_tests_list, group_mni_list,"DPA with A,S,TIV");
res_cere_gw_all_3['ROI']=res_cere_gw_all_3['ROI'].map(lambda x: x[0:-36])
#Experiment 5: control age/sex/infratentorialVolume with direct proportion adjustment method;
dat_cere_gw_all_4, cere_gw_col_all_4 = ctr_tiv(df_all, tar_list, 'InfraTentorialVol', ['age','male', 'is_mni','is_ppmi','is_adni'], 'dpa')
res_cere_gw_all_4 = cal_es(dat_cere_gw_all_4, cere_gw_col_all_4, alpha_, n_permu_, sts_tests_list, group_mni_list,"DPA with A,S,infTV");
res_cere_gw_all_4['ROI']=res_cere_gw_all_4['ROI'].map(lambda x: x[0:-36]);
#Experiment 6: control age/sex/cerebellumVol with rm control group method;
dat_cere_gw_all_5, cere_gw_col_all_5 = ctr_tiv(df_all, tar_list, 'cerebellumVol', ['age','male', 'is_mni','is_ppmi','is_adni'], 'rm_norm')
res_cere_gw_all_5 = cal_es(dat_cere_gw_all_5, cere_gw_col_all_5, alpha_, n_permu_, sts_tests_list, group_mni_list,"RN with A,S,Cere");
res_cere_gw_all_5['ROI']=res_cere_gw_all_5['ROI'].map(lambda x: x[0:-46]);
#Experiment 7: control age/sex/cerebellumVol with direct proportion adjustment method;
dat_cere_gw_all_6, cere_gw_all_col_6 = ctr_tiv(df_all, tar_list, 'cerebellumVol', ['age','male', 'is_mni','is_ppmi','is_adni'], 'dpa')
res_cere_gw_all_6 = cal_es(dat_cere_gw_all_6, cere_gw_all_col_6, alpha_, n_permu_, sts_tests_list, group_mni_list,"DPA with A,S,Cere");
res_cere_gw_all_6['ROI']=res_cere_gw_all_6['ROI'].map(lambda x: x[0:-36]);
res_method_all_df=pd.concat([res_cere_gw_all, res_cere_gw_all_1, res_cere_gw_all_2, res_cere_gw_all_5, res_cere_gw_all_3, res_cere_gw_all_4, res_cere_gw_all_6])
# Out:
# Using  rm_norm
# New columns 19 :  ['Left_Cerebellum_Cortex_eTIV_age_male_is_mni_is_ppmi_is_adni', 'Left_Cerebellum_White_Matter_eTIV_age_male_is_mni_is_ppmi_is_adni', 'Right_Cerebellum_Cortex_eTIV_age_male_is_mni_is_ppmi_is_adni', 'Right_Cerebellum_White_Matter_eTIV_age_male_is_mni_is_ppmi_is_adni', 'Cerebellum_Cortex_eTIV_age_male_is_mni_is_ppmi_is_adni', 'Cerebellum_White_Matter_eTIV_age_male_is_mni_is_ppmi_is_adni', 'Vermis_VI_eTIV_age_male_is_mni_is_ppmi_is_adni', 'Vermis_CrusI_eTIV_age_male_is_mni_is_ppmi_is_adni', 'Vermis_CrusII_eTIV_age_male_is_mni_is_ppmi_is_adni', 'Left_CrusI_eTIV_age_male_is_mni_is_ppmi_is_adni', 'Right_CrusI_eTIV_age_male_is_mni_is_ppmi_is_adni', 'Left_CrusII_eTIV_age_male_is_mni_is_ppmi_is_adni', 'Right_CrusII_eTIV_age_male_is_mni_is_ppmi_is_adni', 'Left_Dentate_eTIV_age_male_is_mni_is_ppmi_is_adni', 'Right_Dentate_eTIV_age_male_is_mni_is_ppmi_is_adni', 'MDTB_1_eTIV_age_male_is_mni_is_ppmi_is_adni', 'MDTB_2_eTIV_age_male_is_mni_is_ppmi_is_adni', 'MDTB_4_eTIV_age_male_is_mni_is_ppmi_is_adni', 'MDTB_5_eTIV_age_male_is_mni_is_ppmi_is_adni']
# Using  rm_norm
# New columns 19 :  ['Left_Cerebellum_Cortex_InfraTentorialVol_age_male_is_mni_is_ppmi_is_adni', 'Left_Cerebellum_White_Matter_InfraTentorialVol_age_male_is_mni_is_ppmi_is_adni', 'Right_Cerebellum_Cortex_InfraTentorialVol_age_male_is_mni_is_ppmi_is_adni', 'Right_Cerebellum_White_Matter_InfraTentorialVol_age_male_is_mni_is_ppmi_is_adni', 'Cerebellum_Cortex_InfraTentorialVol_age_male_is_mni_is_ppmi_is_adni', 'Cerebellum_White_Matter_InfraTentorialVol_age_male_is_mni_is_ppmi_is_adni', 'Vermis_VI_InfraTentorialVol_age_male_is_mni_is_ppmi_is_adni', 'Vermis_CrusI_InfraTentorialVol_age_male_is_mni_is_ppmi_is_adni', 'Vermis_CrusII_InfraTentorialVol_age_male_is_mni_is_ppmi_is_adni', 'Left_CrusI_InfraTentorialVol_age_male_is_mni_is_ppmi_is_adni', 'Right_CrusI_InfraTentorialVol_age_male_is_mni_is_ppmi_is_adni', 'Left_CrusII_InfraTentorialVol_age_male_is_mni_is_ppmi_is_adni', 'Right_CrusII_InfraTentorialVol_age_male_is_mni_is_ppmi_is_adni', 'Left_Dentate_InfraTentorialVol_age_male_is_mni_is_ppmi_is_adni', 'Right_Dentate_InfraTentorialVol_age_male_is_mni_is_ppmi_is_adni', 'MDTB_1_InfraTentorialVol_age_male_is_mni_is_ppmi_is_adni', 'MDTB_2_InfraTentorialVol_age_male_is_mni_is_ppmi_is_adni', 'MDTB_4_InfraTentorialVol_age_male_is_mni_is_ppmi_is_adni', 'MDTB_5_InfraTentorialVol_age_male_is_mni_is_ppmi_is_adni']
# Using  dpa
# New columns 19 :  ['Left_Cerebellum_Cortex_dpa_age_male_is_mni_is_ppmi_is_adni', 'Left_Cerebellum_White_Matter_dpa_age_male_is_mni_is_ppmi_is_adni', 'Right_Cerebellum_Cortex_dpa_age_male_is_mni_is_ppmi_is_adni', 'Right_Cerebellum_White_Matter_dpa_age_male_is_mni_is_ppmi_is_adni', 'Cerebellum_Cortex_dpa_age_male_is_mni_is_ppmi_is_adni', 'Cerebellum_White_Matter_dpa_age_male_is_mni_is_ppmi_is_adni', 'Vermis_VI_dpa_age_male_is_mni_is_ppmi_is_adni', 'Vermis_CrusI_dpa_age_male_is_mni_is_ppmi_is_adni', 'Vermis_CrusII_dpa_age_male_is_mni_is_ppmi_is_adni', 'Left_CrusI_dpa_age_male_is_mni_is_ppmi_is_adni', 'Right_CrusI_dpa_age_male_is_mni_is_ppmi_is_adni', 'Left_CrusII_dpa_age_male_is_mni_is_ppmi_is_adni', 'Right_CrusII_dpa_age_male_is_mni_is_ppmi_is_adni', 'Left_Dentate_dpa_age_male_is_mni_is_ppmi_is_adni', 'Right_Dentate_dpa_age_male_is_mni_is_ppmi_is_adni', 'MDTB_1_dpa_age_male_is_mni_is_ppmi_is_adni', 'MDTB_2_dpa_age_male_is_mni_is_ppmi_is_adni', 'MDTB_4_dpa_age_male_is_mni_is_ppmi_is_adni', 'MDTB_5_dpa_age_male_is_mni_is_ppmi_is_adni']
# Using  dpa
# New columns 19 :  ['Left_Cerebellum_Cortex_dpa_age_male_is_mni_is_ppmi_is_adni', 'Left_Cerebellum_White_Matter_dpa_age_male_is_mni_is_ppmi_is_adni', 'Right_Cerebellum_Cortex_dpa_age_male_is_mni_is_ppmi_is_adni', 'Right_Cerebellum_White_Matter_dpa_age_male_is_mni_is_ppmi_is_adni', 'Cerebellum_Cortex_dpa_age_male_is_mni_is_ppmi_is_adni', 'Cerebellum_White_Matter_dpa_age_male_is_mni_is_ppmi_is_adni', 'Vermis_VI_dpa_age_male_is_mni_is_ppmi_is_adni', 'Vermis_CrusI_dpa_age_male_is_mni_is_ppmi_is_adni', 'Vermis_CrusII_dpa_age_male_is_mni_is_ppmi_is_adni', 'Left_CrusI_dpa_age_male_is_mni_is_ppmi_is_adni', 'Right_CrusI_dpa_age_male_is_mni_is_ppmi_is_adni', 'Left_CrusII_dpa_age_male_is_mni_is_ppmi_is_adni', 'Right_CrusII_dpa_age_male_is_mni_is_ppmi_is_adni', 'Left_Dentate_dpa_age_male_is_mni_is_ppmi_is_adni', 'Right_Dentate_dpa_age_male_is_mni_is_ppmi_is_adni', 'MDTB_1_dpa_age_male_is_mni_is_ppmi_is_adni', 'MDTB_2_dpa_age_male_is_mni_is_ppmi_is_adni', 'MDTB_4_dpa_age_male_is_mni_is_ppmi_is_adni', 'MDTB_5_dpa_age_male_is_mni_is_ppmi_is_adni']
# Using  rm_norm
# New columns 19 :  ['Left_Cerebellum_Cortex_cerebellumVol_age_male_is_mni_is_ppmi_is_adni', 'Left_Cerebellum_White_Matter_cerebellumVol_age_male_is_mni_is_ppmi_is_adni', 'Right_Cerebellum_Cortex_cerebellumVol_age_male_is_mni_is_ppmi_is_adni', 'Right_Cerebellum_White_Matter_cerebellumVol_age_male_is_mni_is_ppmi_is_adni', 'Cerebellum_Cortex_cerebellumVol_age_male_is_mni_is_ppmi_is_adni', 'Cerebellum_White_Matter_cerebellumVol_age_male_is_mni_is_ppmi_is_adni', 'Vermis_VI_cerebellumVol_age_male_is_mni_is_ppmi_is_adni', 'Vermis_CrusI_cerebellumVol_age_male_is_mni_is_ppmi_is_adni', 'Vermis_CrusII_cerebellumVol_age_male_is_mni_is_ppmi_is_adni', 'Left_CrusI_cerebellumVol_age_male_is_mni_is_ppmi_is_adni', 'Right_CrusI_cerebellumVol_age_male_is_mni_is_ppmi_is_adni', 'Left_CrusII_cerebellumVol_age_male_is_mni_is_ppmi_is_adni', 'Right_CrusII_cerebellumVol_age_male_is_mni_is_ppmi_is_adni', 'Left_Dentate_cerebellumVol_age_male_is_mni_is_ppmi_is_adni', 'Right_Dentate_cerebellumVol_age_male_is_mni_is_ppmi_is_adni', 'MDTB_1_cerebellumVol_age_male_is_mni_is_ppmi_is_adni', 'MDTB_2_cerebellumVol_age_male_is_mni_is_ppmi_is_adni', 'MDTB_4_cerebellumVol_age_male_is_mni_is_ppmi_is_adni', 'MDTB_5_cerebellumVol_age_male_is_mni_is_ppmi_is_adni']
# Using  dpa
# New columns 19 :  ['Left_Cerebellum_Cortex_dpa_age_male_is_mni_is_ppmi_is_adni', 'Left_Cerebellum_White_Matter_dpa_age_male_is_mni_is_ppmi_is_adni', 'Right_Cerebellum_Cortex_dpa_age_male_is_mni_is_ppmi_is_adni', 'Right_Cerebellum_White_Matter_dpa_age_male_is_mni_is_ppmi_is_adni', 'Cerebellum_Cortex_dpa_age_male_is_mni_is_ppmi_is_adni', 'Cerebellum_White_Matter_dpa_age_male_is_mni_is_ppmi_is_adni', 'Vermis_VI_dpa_age_male_is_mni_is_ppmi_is_adni', 'Vermis_CrusI_dpa_age_male_is_mni_is_ppmi_is_adni', 'Vermis_CrusII_dpa_age_male_is_mni_is_ppmi_is_adni', 'Left_CrusI_dpa_age_male_is_mni_is_ppmi_is_adni', 'Right_CrusI_dpa_age_male_is_mni_is_ppmi_is_adni', 'Left_CrusII_dpa_age_male_is_mni_is_ppmi_is_adni', 'Right_CrusII_dpa_age_male_is_mni_is_ppmi_is_adni', 'Left_Dentate_dpa_age_male_is_mni_is_ppmi_is_adni', 'Right_Dentate_dpa_age_male_is_mni_is_ppmi_is_adni', 'MDTB_1_dpa_age_male_is_mni_is_ppmi_is_adni', 'MDTB_2_dpa_age_male_is_mni_is_ppmi_is_adni', 'MDTB_4_dpa_age_male_is_mni_is_ppmi_is_adni', 'MDTB_5_dpa_age_male_is_mni_is_ppmi_is_adni']

# %%
# Vis for methods sensitivity analysis.
C_MAP='coolwarm_r'; VMIN=0; VMAX=0.1;
order_list=['Cohen_d','Cohen_d_RN with A,S,TIV','Cohen_d_RN with A,S,infTV', 'Cohen_d_RN with A,S,Cere',  
             'Cohen_d_DPA with A,S,TIV', 'Cohen_d_DPA with A,S,infTV', 'Cohen_d_RN with A,S,Cere', 
             'rank_sum', 'rank_sum_RN with A,S,TIV', 'rank_sum_RN with A,S,infTV', 'rank_sum_RN with A,S,Cere',
             'rank_sum_DPA with A,S,TIV', 'rank_sum_DPA with A,S,infTV', 'rank_sum_DPA with A,S,Cere']

vis_df = res_method_all_df.copy()
es_df=vis_df[['ROI','test','ES']]; p_df=vis_df[['ROI','test','p_val']]
es_df = es_df.pivot("ROI", "test"); p_df = p_df.pivot("ROI", "test"); 

# reorder columns
es_df_=es_df[pd.MultiIndex.from_tuples([('ES', x) for x in order_list], names=[None, 'test'])]
p_df_ = p_df[pd.MultiIndex.from_tuples([('p_val', x) for x in order_list], names=[None, 'test'])]

# create multiple comparison mask
pass_df, mask_df=creat_Bonf_df(p_df_, 0.05, df_n_comp)
anno_df =pd.DataFrame(np.array(es_df_))*pd.DataFrame(np.array(1-mask_df));
# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(30, 9))
ax1=sns.heatmap(p_df_, annot=anno_df, fmt=".4f", mask=mask_df,
                linewidths=.5, cmap=C_MAP, vmin=VMIN, vmax=VMAX, ax=ax)
ax1.set_title('Metods sensitivity analysis for ET and NC Cerebellum Volemetry comparison for all 3 cohorts (survive the Bonf. correction)')
f, ax = plt.subplots(figsize=(30, 9))
ax2=sns.heatmap(p_df_, annot=es_df_, fmt=".4f",
                linewidths=.5, cmap=C_MAP, vmin=VMIN, vmax=VMAX, ax=ax)
ax2.set_title('Metods sensitivity analysis for ET and NC Cerebellum Volemetry comparison for all 3 cohorts (full inform)')
# Out:
# Text(0.5, 1.0, 'Metods sensitivity analysis for ET and NC Cerebellum Volemetry comparison for all 3 cohorts (full inform)')

# %% [markdown]
# # GLM analysis for MNI dataset
#
# 1. Testing Models: Voi=b0+b1*age+b2*sex+b3*eIV+b4*group for 'Left_Cerebellum_Cortex', 'Left_Cerebellum_White_Matter', 'Right_Cerebellum_Cortex', 'Right_Cerebellum_White_Matter';
#
# 2. Testing Models: Voi=b0+b1*age+b2*sex+b3*eIV+b4*group for 'Vermis_VI', 'Vermis_CrusI', 'Vermis_CrusII', 'Left_CrusI', 'Right_CrusI', 'Left_CrusII', 'Right_CrusII','Left_Dentate', 'Right_Dentate', 'MDTB_1', 'MDTB_2', 'MDTB_4', 'MDTB_5';

# %%
tmp_df.columns
# Out:
# Index(['age', 'sex', 'group', 'site', 'eTIV', 'SupraTentorialVol',
#        'SupraTentorialVolNotVent', 'Left_Cerebellum_White_Matter',
#        'Left_Cerebellum_Cortex', 'Right_Cerebellum_White_Matter',
#        'Right_Cerebellum_Cortex', 'Left_I_IV', 'Left_V', 'Left_VI',
#        'Left_CrusI', 'Left_CrusII', 'Left_VIIb', 'Left_VIIIa', 'Left_VIIIb',
#        'Left_IX', 'Left_X', 'Left_Dentate', 'Left_Interposed',
#        'Left_Fastigial', 'Right_I_IV', 'Right_V', 'Right_VI', 'Right_CrusI',
#        'Right_CrusII', 'Right_VIIb', 'Right_VIIIa', 'Right_VIIIb', 'Right_IX',
#        'Right_X', 'Right_Dentate', 'Right_Interposed', 'Right_Fastigial',
#        'Vermis_VI', 'Vermis_CrusI', 'Vermis_CrusII', 'Vermis_VIIb',
#        'Vermis_VIIIa', 'Vermis_VIIIb', 'Vermis_IX', 'Vermis_X', 'MDTB_1',
#        'MDTB_2', 'MDTB_3', 'MDTB_4', 'MDTB_5', 'MDTB_6', 'MDTB_7', 'MDTB_8',
#        'MDTB_9', 'MDTB_10', 'Cerebellum_White_Matter', 'Cerebellum_Cortex',
#        'cerebellumVol', 'InfraTentorialVol', 'male'],
#       dtype='object')

# %%
# GLM Model 
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.formula.api import glm
import statsmodels.stats as sts
from utils_et_biomarker.utils import glm_test, rep_model

# basic GLM
tmp_df = df.copy() 
tmp_df.loc[:,'eTIV'] = tmp_df['eTIV']-tmp_df.eTIV.mean();
tmp_df.loc[:,'cerebellumVol'] = tmp_df['cerebellumVol']-tmp_df.eTIV.mean();
tmp_df.loc[:,'InfraTentorialVol'] = tmp_df['InfraTentorialVol']-tmp_df.eTIV.mean();
for x in tar_list:
    tmp_df.loc[:,x] = (tmp_df[x]-tmp_df[x].mean())/1000;

# using eTIV as covariate
covariate_model_str = '~age+male+eTIV+C(group, Treatment(reference="NC"))';
covariate_dict = glm_test(tmp_df, tar_list, covariate_model_str);
rep_model(covariate_dict)

# using InfraTentorialVol as covariate
covariate_model_str_infra = '~age+male+InfraTentorialVol+C(group, Treatment(reference="NC"))';
covariate_dict_infra = glm_test(tmp_df, tar_list, covariate_model_str_infra);
rep_model(covariate_dict_infra)

# using cerebellumVol as covariate
covariate_model_str_cere = '~age+male+cerebellumVol+C(group, Treatment(reference="NC"))';
covariate_dict_cere = glm_test(tmp_df, tar_list, covariate_model_str_cere);
rep_model(covariate_dict_cere)
# Out:
# Left_Cerebellum_Cortex~age+male+eTIV+C(group, Treatment(reference="NC"))
#
#                             Results: Generalized linear model
# =========================================================================================
# Model:                      GLM                           AIC:                   369.5056
# Link Function:              identity                      BIC:                   420.5880
# Dependent Variable:         Left_Cerebellum_Cortex        Log-Likelihood:        -179.75
# Date:                       2021-10-08 06:24              LL-Null:               -205.80
# No. Observations:           70                            Deviance:              696.74
# Df Model:                   4                             Pearson chi2:          697.
# Df Residuals:               65                            Scale:                 10.719
# Method:                     IRLS
# -----------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025  0.975]
# -----------------------------------------------------------------------------------------
# Intercept                                  8.0627   2.7749  2.9056 0.0037  2.6240 13.5014
# C(group, Treatment(reference="NC"))[T.ET]  1.2987   1.0906  1.1908 0.2337 -0.8388  3.4361
# age                                       -0.1492   0.0445 -3.3502 0.0008 -0.2365 -0.0619
# male                                       1.4517   1.0190  1.4247 0.1543 -0.5455  3.4489
# eTIV                                       0.0000   0.0000  4.6590 0.0000  0.0000  0.0000
# =========================================================================================
#
#
#
# Left_Cerebellum_White_Matter~age+male+eTIV+C(group, Treatment(reference="NC"))
#
#                            Results: Generalized linear model
# ========================================================================================
# Model:                    GLM                              AIC:                266.8347
# Link Function:            identity                         BIC:                -115.4287
# Dependent Variable:       Left_Cerebellum_White_Matter     Log-Likelihood:     -128.42
# Date:                     2021-10-08 06:24                 LL-Null:            -131.57
# No. Observations:         70                               Deviance:           160.72
# Df Model:                 4                                Pearson chi2:       161.
# Df Residuals:             65                               Scale:              2.4727
# Method:                   IRLS
# ----------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025 0.975]
# ----------------------------------------------------------------------------------------
# Intercept                                  0.8235   1.3328  0.6179 0.5367 -1.7887 3.4356
# C(group, Treatment(reference="NC"))[T.ET] -0.1119   0.5238 -0.2136 0.8308 -1.1385 0.9147
# age                                       -0.0091   0.0214 -0.4245 0.6712 -0.0510 0.0328
# male                                      -0.2391   0.4894 -0.4885 0.6252 -1.1983 0.7201
# eTIV                                       0.0000   0.0000  2.2866 0.0222  0.0000 0.0000
# ========================================================================================
#
#
#
# Right_Cerebellum_Cortex~age+male+eTIV+C(group, Treatment(reference="NC"))
#
#                             Results: Generalized linear model
# =========================================================================================
# Model:                     GLM                            AIC:                   379.3446
# Link Function:             identity                       BIC:                   525.7364
# Dependent Variable:        Right_Cerebellum_Cortex        Log-Likelihood:        -184.67
# Date:                      2021-10-08 06:24               LL-Null:               -208.67
# No. Observations:          70                             Deviance:              801.89
# Df Model:                  4                              Pearson chi2:          802.
# Df Residuals:              65                             Scale:                 12.337
# Method:                    IRLS
# -----------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025  0.975]
# -----------------------------------------------------------------------------------------
# Intercept                                  7.5496   2.9769  2.5360 0.0112  1.7149 13.3843
# C(group, Treatment(reference="NC"))[T.ET]  0.7770   1.1700  0.6641 0.5066 -1.5161  3.0700
# age                                       -0.1423   0.0478 -2.9794 0.0029 -0.2360 -0.0487
# male                                       1.9474   1.0932  1.7814 0.0748 -0.1952  4.0900
# eTIV                                       0.0000   0.0000  4.1707 0.0000  0.0000  0.0000
# =========================================================================================
#
#
#
# Right_Cerebellum_White_Matter~age+male+eTIV+C(group, Treatment(reference="NC"))
#
#                            Results: Generalized linear model
# ========================================================================================
# Model:                   GLM                               AIC:                263.1360
# Link Function:           identity                          BIC:                -123.7007
# Dependent Variable:      Right_Cerebellum_White_Matter     Log-Likelihood:     -126.57
# Date:                    2021-10-08 06:24                  LL-Null:            -131.05
# No. Observations:        70                                Deviance:           152.45
# Df Model:                4                                 Pearson chi2:       152.
# Df Residuals:            65                                Scale:              2.3454
# Method:                  IRLS
# ----------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025 0.975]
# ----------------------------------------------------------------------------------------
# Intercept                                  1.2259   1.2980  0.9444 0.3450 -1.3182 3.7699
# C(group, Treatment(reference="NC"))[T.ET] -0.5263   0.5101 -1.0316 0.3022 -1.5261 0.4736
# age                                       -0.0123   0.0208 -0.5918 0.5540 -0.0532 0.0285
# male                                      -0.1882   0.4767 -0.3948 0.6930 -1.1224 0.7461
# eTIV                                       0.0000   0.0000  2.2584 0.0239  0.0000 0.0000
# ========================================================================================
#
#
#
# Cerebellum_Cortex~age+male+eTIV+C(group, Treatment(reference="NC"))
#
#                             Results: Generalized linear model
# =========================================================================================
# Model:                        GLM                       AIC:                    468.8607
# Link Function:                identity                  BIC:                    2604.4967
# Dependent Variable:           Cerebellum_Cortex         Log-Likelihood:         -229.43
# Date:                         2021-10-08 06:24          LL-Null:                -255.32
# No. Observations:             70                        Deviance:               2880.6
# Df Model:                     4                         Pearson chi2:           2.88e+03
# Df Residuals:                 65                        Scale:                  44.318
# Method:                       IRLS
# -----------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025  0.975]
# -----------------------------------------------------------------------------------------
# Intercept                                 15.6123   5.6423  2.7670 0.0057  4.5536 26.6711
# C(group, Treatment(reference="NC"))[T.ET]  2.0757   2.2175  0.9360 0.3492 -2.2705  6.4218
# age                                       -0.2915   0.0905 -3.2196 0.0013 -0.4690 -0.1140
# male                                       3.3992   2.0720  1.6405 0.1009 -0.6618  7.4602
# eTIV                                       0.0000   0.0000  4.4918 0.0000  0.0000  0.0000
# =========================================================================================
#
#
#
# Cerebellum_White_Matter~age+male+eTIV+C(group, Treatment(reference="NC"))
#
#                            Results: Generalized linear model
# ========================================================================================
# Model:                      GLM                           AIC:                  358.4913
# Link Function:              identity                      BIC:                  319.1481
# Dependent Variable:         Cerebellum_White_Matter       Log-Likelihood:       -174.25
# Date:                       2021-10-08 06:24              LL-Null:              -178.02
# No. Observations:           70                            Deviance:             595.30
# Df Model:                   4                             Pearson chi2:         595.
# Df Residuals:               65                            Scale:                9.1585
# Method:                     IRLS
# ----------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025 0.975]
# ----------------------------------------------------------------------------------------
# Intercept                                  2.0493   2.5650  0.7990 0.4243 -2.9779 7.0766
# C(group, Treatment(reference="NC"))[T.ET] -0.6382   1.0080 -0.6331 0.5267 -2.6139 1.3376
# age                                       -0.0214   0.0412 -0.5200 0.6030 -0.1021 0.0593
# male                                      -0.4273   0.9419 -0.4536 0.6501 -2.2734 1.4188
# eTIV                                       0.0000   0.0000  2.3310 0.0198  0.0000 0.0000
# ========================================================================================
#
#
#
# Vermis_VI~age+male+eTIV+C(group, Treatment(reference="NC"))
#
#                            Results: Generalized linear model
# ========================================================================================
# Model:                        GLM                      AIC:                    -54.4408
# Link Function:                identity                 BIC:                    -274.5198
# Dependent Variable:           Vermis_VI                Log-Likelihood:         32.220
# Date:                         2021-10-08 06:24         LL-Null:                15.282
# No. Observations:             70                       Deviance:               1.6324
# Df Model:                     4                        Pearson chi2:           1.63
# Df Residuals:                 65                       Scale:                  0.025113
# Method:                       IRLS
# ----------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025 0.975]
# ----------------------------------------------------------------------------------------
# Intercept                                  0.1566   0.1343  1.1658 0.2437 -0.1067 0.4198
# C(group, Treatment(reference="NC"))[T.ET]  0.0312   0.0528  0.5908 0.5547 -0.0723 0.1346
# age                                       -0.0033   0.0022 -1.5368 0.1243 -0.0075 0.0009
# male                                       0.0625   0.0493  1.2667 0.2053 -0.0342 0.1591
# eTIV                                       0.0000   0.0000  4.0020 0.0001  0.0000 0.0000
# ========================================================================================
#
#
#
# Vermis_CrusI~age+male+eTIV+C(group, Treatment(reference="NC"))
#
#                            Results: Generalized linear model
# ========================================================================================
# Model:                       GLM                      AIC:                    -558.4616
# Link Function:               identity                 BIC:                    -276.1510
# Dependent Variable:          Vermis_CrusI             Log-Likelihood:         284.23
# Date:                        2021-10-08 06:24         LL-Null:                280.64
# No. Observations:            70                       Deviance:               0.0012183
# Df Model:                    4                        Pearson chi2:           0.00122
# Df Residuals:                65                       Scale:                  1.8744e-05
# Method:                      IRLS
# ----------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025 0.975]
# ----------------------------------------------------------------------------------------
# Intercept                                  0.0017   0.0037  0.4546 0.6494 -0.0055 0.0089
# C(group, Treatment(reference="NC"))[T.ET]  0.0022   0.0014  1.5159 0.1296 -0.0006 0.0050
# age                                       -0.0000   0.0001 -0.8081 0.4190 -0.0002 0.0001
# male                                       0.0004   0.0013  0.2821 0.7779 -0.0023 0.0030
# eTIV                                       0.0000   0.0000  1.5062 0.1320 -0.0000 0.0000
# ========================================================================================
#
#
#
# Vermis_CrusII~age+male+eTIV+C(group, Treatment(reference="NC"))
#
#                            Results: Generalized linear model
# ========================================================================================
# Model:                        GLM                      AIC:                    -245.5862
# Link Function:                identity                 BIC:                    -276.0458
# Dependent Variable:           Vermis_CrusII            Log-Likelihood:         127.79
# Date:                         2021-10-08 06:24         LL-Null:                113.58
# No. Observations:             70                       Deviance:               0.10639
# Df Model:                     4                        Pearson chi2:           0.106
# Df Residuals:                 65                       Scale:                  0.0016368
# Method:                       IRLS
# ----------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025 0.975]
# ----------------------------------------------------------------------------------------
# Intercept                                 -0.0051   0.0343 -0.1493 0.8814 -0.0723 0.0621
# C(group, Treatment(reference="NC"))[T.ET]  0.0005   0.0135  0.0357 0.9715 -0.0259 0.0269
# age                                       -0.0001   0.0006 -0.1999 0.8415 -0.0012 0.0010
# male                                       0.0172   0.0126  1.3696 0.1708 -0.0074 0.0419
# eTIV                                       0.0000   0.0000  3.5514 0.0004  0.0000 0.0000
# ========================================================================================
#
#
#
# Left_CrusI~age+male+eTIV+C(group, Treatment(reference="NC"))
#
#                             Results: Generalized linear model
# =========================================================================================
# Model:                       GLM                       AIC:                     204.6591
# Link Function:               identity                  BIC:                     -210.0328
# Dependent Variable:          Left_CrusI                Log-Likelihood:          -97.330
# Date:                        2021-10-08 06:24          LL-Null:                 -128.63
# No. Observations:            70                        Deviance:                66.119
# Df Model:                    4                         Pearson chi2:            66.1
# Df Residuals:                65                        Scale:                   1.0172
# Method:                      IRLS
# -----------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025  0.975]
# -----------------------------------------------------------------------------------------
# Intercept                                  1.3513   0.8548  1.5808 0.1139 -0.3242  3.0267
# C(group, Treatment(reference="NC"))[T.ET]  0.6157   0.3360  1.8326 0.0669 -0.0428  1.2741
# age                                       -0.0282   0.0137 -2.0560 0.0398 -0.0551 -0.0013
# male                                       0.2346   0.3139  0.7473 0.4549 -0.3807  0.8498
# eTIV                                       0.0000   0.0000  5.9730 0.0000  0.0000  0.0000
# =========================================================================================
#
#
#
# Right_CrusI~age+male+eTIV+C(group, Treatment(reference="NC"))
#
#                            Results: Generalized linear model
# ========================================================================================
# Model:                        GLM                      AIC:                    220.4232
# Link Function:                identity                 BIC:                    -193.3326
# Dependent Variable:           Right_CrusI              Log-Likelihood:         -105.21
# Date:                         2021-10-08 06:24         LL-Null:                -122.23
# No. Observations:             70                       Deviance:               82.820
# Df Model:                     4                        Pearson chi2:           82.8
# Df Residuals:                 65                       Scale:                  1.2741
# Method:                       IRLS
# ----------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025 0.975]
# ----------------------------------------------------------------------------------------
# Intercept                                  1.4703   0.9567  1.5369 0.1243 -0.4048 3.3454
# C(group, Treatment(reference="NC"))[T.ET]  0.4736   0.3760  1.2596 0.2078 -0.2633 1.2105
# age                                       -0.0285   0.0154 -1.8549 0.0636 -0.0586 0.0016
# male                                       0.2003   0.3513  0.5702 0.5686 -0.4883 0.8889
# eTIV                                       0.0000   0.0000  4.3987 0.0000  0.0000 0.0000
# ========================================================================================
#
#
#
# Left_CrusII~age+male+eTIV+C(group, Treatment(reference="NC"))
#
#                            Results: Generalized linear model
# ========================================================================================
# Model:                        GLM                      AIC:                    157.3951
# Link Function:                identity                 BIC:                    -242.4938
# Dependent Variable:           Left_CrusII              Log-Likelihood:         -73.698
# Date:                         2021-10-08 06:24         LL-Null:                -89.754
# No. Observations:             70                       Deviance:               33.658
# Df Model:                     4                        Pearson chi2:           33.7
# Df Residuals:                 65                       Scale:                  0.51782
# Method:                       IRLS
# ----------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025 0.975]
# ----------------------------------------------------------------------------------------
# Intercept                                  0.6856   0.6099  1.1241 0.2610 -0.5098 1.8810
# C(group, Treatment(reference="NC"))[T.ET]  0.1685   0.2397  0.7029 0.4821 -0.3013 0.6383
# age                                       -0.0138   0.0098 -1.4092 0.1588 -0.0330 0.0054
# male                                       0.1821   0.2240  0.8133 0.4161 -0.2568 0.6211
# eTIV                                       0.0000   0.0000  4.1986 0.0000  0.0000 0.0000
# ========================================================================================
#
#
#
# Right_CrusII~age+male+eTIV+C(group, Treatment(reference="NC"))
#
#                            Results: Generalized linear model
# ========================================================================================
# Model:                        GLM                      AIC:                    156.6690
# Link Function:                identity                 BIC:                    -242.8411
# Dependent Variable:           Right_CrusII             Log-Likelihood:         -73.334
# Date:                         2021-10-08 06:24         LL-Null:                -88.425
# No. Observations:             70                       Deviance:               33.311
# Df Model:                     4                        Pearson chi2:           33.3
# Df Residuals:                 65                       Scale:                  0.51248
# Method:                       IRLS
# ----------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025 0.975]
# ----------------------------------------------------------------------------------------
# Intercept                                  0.9457   0.6067  1.5586 0.1191 -0.2435 2.1349
# C(group, Treatment(reference="NC"))[T.ET]  0.1538   0.2385  0.6449 0.5190 -0.3136 0.6211
# age                                       -0.0189   0.0097 -1.9389 0.0525 -0.0380 0.0002
# male                                       0.2985   0.2228  1.3397 0.1803 -0.1382 0.7352
# eTIV                                       0.0000   0.0000  3.5544 0.0004  0.0000 0.0000
# ========================================================================================
#
#
#
# Left_Dentate~age+male+eTIV+C(group, Treatment(reference="NC"))
#
#                            Results: Generalized linear model
# ========================================================================================
# Model:                        GLM                      AIC:                    -85.9128
# Link Function:                identity                 BIC:                    -275.1109
# Dependent Variable:           Left_Dentate             Log-Likelihood:         47.956
# Date:                         2021-10-08 06:24         LL-Null:                26.591
# No. Observations:             70                       Deviance:               1.0413
# Df Model:                     4                        Pearson chi2:           1.04
# Df Residuals:                 65                       Scale:                  0.016019
# Method:                       IRLS
# ----------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025 0.975]
# ----------------------------------------------------------------------------------------
# Intercept                                 -0.0668   0.1073 -0.6230 0.5333 -0.2771 0.1434
# C(group, Treatment(reference="NC"))[T.ET] -0.0353   0.0422 -0.8375 0.4023 -0.1179 0.0473
# age                                        0.0007   0.0017  0.4306 0.6668 -0.0026 0.0041
# male                                       0.0534   0.0394  1.3560 0.1751 -0.0238 0.1306
# eTIV                                       0.0000   0.0000  4.5772 0.0000  0.0000 0.0000
# ========================================================================================
#
#
#
# Right_Dentate~age+male+eTIV+C(group, Treatment(reference="NC"))
#
#                            Results: Generalized linear model
# ========================================================================================
# Model:                        GLM                      AIC:                    -67.0040
# Link Function:                identity                 BIC:                    -274.7880
# Dependent Variable:           Right_Dentate            Log-Likelihood:         38.502
# Date:                         2021-10-08 06:24         LL-Null:                13.511
# No. Observations:             70                       Deviance:               1.3642
# Df Model:                     4                        Pearson chi2:           1.36
# Df Residuals:                 65                       Scale:                  0.020988
# Method:                       IRLS
# ----------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025 0.975]
# ----------------------------------------------------------------------------------------
# Intercept                                 -0.0236   0.1228 -0.1924 0.8474 -0.2643 0.2170
# C(group, Treatment(reference="NC"))[T.ET] -0.0568   0.0483 -1.1780 0.2388 -0.1514 0.0377
# age                                        0.0002   0.0020  0.0783 0.9376 -0.0037 0.0040
# male                                       0.0634   0.0451  1.4055 0.1599 -0.0250 0.1517
# eTIV                                       0.0000   0.0000  5.0269 0.0000  0.0000 0.0000
# ========================================================================================
#
#
#
# MDTB_1~age+male+eTIV+C(group, Treatment(reference="NC"))
#
#                             Results: Generalized linear model
# =========================================================================================
# Model:                       GLM                       AIC:                     173.8440
# Link Function:               identity                  BIC:                     -233.5781
# Dependent Variable:          MDTB_1                    Log-Likelihood:          -81.922
# Date:                        2021-10-08 06:24          LL-Null:                 -122.75
# No. Observations:            70                        Deviance:                42.574
# Df Model:                    4                         Pearson chi2:            42.6
# Df Residuals:                65                        Scale:                   0.65499
# Method:                      IRLS
# -----------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025  0.975]
# -----------------------------------------------------------------------------------------
# Intercept                                  1.6199   0.6859  2.3615 0.0182  0.2754  2.9643
# C(group, Treatment(reference="NC"))[T.ET]  0.3634   0.2696  1.3480 0.1777 -0.1650  0.8917
# age                                       -0.0298   0.0110 -2.7068 0.0068 -0.0514 -0.0082
# male                                       0.1956   0.2519  0.7765 0.4375 -0.2981  0.6893
# eTIV                                       0.0000   0.0000  6.9892 0.0000  0.0000  0.0000
# =========================================================================================
#
#
#
# MDTB_2~age+male+eTIV+C(group, Treatment(reference="NC"))
#
#                             Results: Generalized linear model
# =========================================================================================
# Model:                       GLM                       AIC:                     172.7613
# Link Function:               identity                  BIC:                     -234.2315
# Dependent Variable:          MDTB_2                    Log-Likelihood:          -81.381
# Date:                        2021-10-08 06:24          LL-Null:                 -119.33
# No. Observations:            70                        Deviance:                41.921
# Df Model:                    4                         Pearson chi2:            41.9
# Df Residuals:                65                        Scale:                   0.64493
# Method:                      IRLS
# -----------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025  0.975]
# -----------------------------------------------------------------------------------------
# Intercept                                  1.4509   0.6807  2.1317 0.0330  0.1169  2.7850
# C(group, Treatment(reference="NC"))[T.ET]  0.3587   0.2675  1.3410 0.1799 -0.1656  0.8830
# age                                       -0.0272   0.0109 -2.4890 0.0128 -0.0486 -0.0058
# male                                       0.1962   0.2500  0.7849 0.4325 -0.2937  0.6861
# eTIV                                       0.0000   0.0000  6.7233 0.0000  0.0000  0.0000
# =========================================================================================
#
#
#
# MDTB_4~age+male+eTIV+C(group, Treatment(reference="NC"))
#
#                             Results: Generalized linear model
# =========================================================================================
# Model:                       GLM                       AIC:                     268.1757
# Link Function:               identity                  BIC:                     -112.3199
# Dependent Variable:          MDTB_4                    Log-Likelihood:          -129.09
# Date:                        2021-10-08 06:24          LL-Null:                 -148.66
# No. Observations:            70                        Deviance:                163.83
# Df Model:                    4                         Pearson chi2:            164.
# Df Residuals:                65                        Scale:                   2.5205
# Method:                      IRLS
# -----------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025  0.975]
# -----------------------------------------------------------------------------------------
# Intercept                                  2.3296   1.3456  1.7313 0.0834 -0.3077  4.9669
# C(group, Treatment(reference="NC"))[T.ET]  0.5615   0.5288  1.0619 0.2883 -0.4749  1.5980
# age                                       -0.0461   0.0216 -2.1345 0.0328 -0.0884 -0.0038
# male                                       0.5546   0.4941  1.1224 0.2617 -0.4138  1.5231
# eTIV                                       0.0000   0.0000  4.3788 0.0000  0.0000  0.0000
# =========================================================================================
#
#
#
# MDTB_5~age+male+eTIV+C(group, Treatment(reference="NC"))
#
#                             Results: Generalized linear model
# =========================================================================================
# Model:                       GLM                       AIC:                     192.6502
# Link Function:               identity                  BIC:                     -220.4563
# Dependent Variable:          MDTB_5                    Log-Likelihood:          -91.325
# Date:                        2021-10-08 06:24          LL-Null:                 -119.66
# No. Observations:            70                        Deviance:                55.696
# Df Model:                    4                         Pearson chi2:            55.7
# Df Residuals:                65                        Scale:                   0.85686
# Method:                      IRLS
# -----------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025  0.975]
# -----------------------------------------------------------------------------------------
# Intercept                                  1.4214   0.7846  1.8117 0.0700 -0.1163  2.9591
# C(group, Treatment(reference="NC"))[T.ET]  0.4494   0.3083  1.4574 0.1450 -0.1550  1.0537
# age                                       -0.0282   0.0126 -2.2421 0.0250 -0.0529 -0.0036
# male                                       0.2657   0.2881  0.9223 0.3564 -0.2989  0.8304
# eTIV                                       0.0000   0.0000  5.5989 0.0000  0.0000  0.0000
# =========================================================================================
#
#
#
# Left_Cerebellum_Cortex~age+male+InfraTentorialVol+C(group, Treatment(reference="NC"))
#
#                             Results: Generalized linear model
# =========================================================================================
# Model:                      GLM                           AIC:                   376.2182
# Link Function:              identity                      BIC:                   490.7100
# Dependent Variable:         Left_Cerebellum_Cortex        Log-Likelihood:        -183.11
# Date:                       2021-10-08 06:24              LL-Null:               -203.81
# No. Observations:           70                            Deviance:              766.86
# Df Model:                   4                             Pearson chi2:          767.
# Df Residuals:               65                            Scale:                 11.798
# Method:                     IRLS
# -----------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025  0.975]
# -----------------------------------------------------------------------------------------
# Intercept                                 -2.9140   3.3139 -0.8793 0.3792 -9.4091  3.5811
# C(group, Treatment(reference="NC"))[T.ET]  0.2531   1.1672  0.2168 0.8283 -2.0347  2.5408
# age                                       -0.1692   0.0485 -3.4901 0.0005 -0.2643 -0.0742
# male                                       2.2495   1.0178  2.2101 0.0271  0.2546  4.2444
# InfraTentorialVol                          0.0000   0.0000  3.7119 0.0002  0.0000  0.0000
# =========================================================================================
#
#
#
# Left_Cerebellum_White_Matter~age+male+InfraTentorialVol+C(group, Treatment(reference="NC"))
#
#                            Results: Generalized linear model
# ========================================================================================
# Model:                    GLM                              AIC:                272.1637
# Link Function:            identity                         BIC:                -102.7154
# Dependent Variable:       Left_Cerebellum_White_Matter     Log-Likelihood:     -131.08
# Date:                     2021-10-08 06:24                 LL-Null:            -131.63
# No. Observations:         70                               Deviance:           173.44
# Df Model:                 4                                Pearson chi2:       173.
# Df Residuals:             65                               Scale:              2.6683
# Method:                   IRLS
# ----------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025 0.975]
# ----------------------------------------------------------------------------------------
# Intercept                                 -0.4036   1.5760 -0.2561 0.7979 -3.4924 2.6853
# C(group, Treatment(reference="NC"))[T.ET] -0.1848   0.5551 -0.3330 0.7392 -1.2728 0.9032
# age                                       -0.0023   0.0231 -0.1013 0.9193 -0.0475 0.0429
# male                                       0.2992   0.4840  0.6182 0.5365 -0.6495 1.2479
# InfraTentorialVol                          0.0000   0.0000  0.2841 0.7764 -0.0000 0.0000
# ========================================================================================
#
#
#
# Right_Cerebellum_Cortex~age+male+InfraTentorialVol+C(group, Treatment(reference="NC"))
#
#                             Results: Generalized linear model
# ==========================================================================================
# Model:                      GLM                            AIC:                   380.9829
# Link Function:              identity                       BIC:                   544.7248
# Dependent Variable:         Right_Cerebellum_Cortex        Log-Likelihood:        -185.49
# Date:                       2021-10-08 06:24               LL-Null:               -208.18
# No. Observations:           70                             Deviance:              820.88
# Df Model:                   4                              Pearson chi2:          821.
# Df Residuals:               65                             Scale:                 12.629
# Method:                     IRLS
# ------------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025   0.975]
# ------------------------------------------------------------------------------------------
# Intercept                                 -3.9245   3.4286 -1.1446 0.2524 -10.6444  2.7955
# C(group, Treatment(reference="NC"))[T.ET] -0.3461   1.2077 -0.2866 0.7744  -2.7131  2.0208
# age                                       -0.1694   0.0502 -3.3776 0.0007  -0.2678 -0.0711
# male                                       2.4735   1.0531  2.3489 0.0188   0.4096  4.5375
# InfraTentorialVol                          0.0000   0.0000  3.9356 0.0001   0.0000  0.0000
# ==========================================================================================
#
#
#
# Right_Cerebellum_White_Matter~age+male+InfraTentorialVol+C(group, Treatment(reference="NC"))
#
#                            Results: Generalized linear model
# ========================================================================================
# Model:                   GLM                               AIC:                268.4080
# Link Function:           identity                          BIC:                -111.7754
# Dependent Variable:      Right_Cerebellum_White_Matter     Log-Likelihood:     -129.20
# Date:                    2021-10-08 06:24                  LL-Null:            -131.01
# No. Observations:        70                                Deviance:           164.38
# Df Model:                4                                 Pearson chi2:       164.
# Df Residuals:            65                                Scale:              2.5289
# Method:                  IRLS
# ----------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025 0.975]
# ----------------------------------------------------------------------------------------
# Intercept                                  0.1811   1.5343  0.1181 0.9060 -2.8259 3.1882
# C(group, Treatment(reference="NC"))[T.ET] -0.5791   0.5404 -1.0716 0.2839 -1.6383 0.4801
# age                                       -0.0047   0.0225 -0.2093 0.8342 -0.0487 0.0393
# male                                       0.3646   0.4712  0.7736 0.4392 -0.5590 1.2882
# InfraTentorialVol                          0.0000   0.0000  0.1214 0.9034 -0.0000 0.0000
# ========================================================================================
#
#
#
# Cerebellum_Cortex~age+male+InfraTentorialVol+C(group, Treatment(reference="NC"))
#
#                             Results: Generalized linear model
# ==========================================================================================
# Model:                       GLM                        AIC:                     473.0894
# Link Function:               identity                   BIC:                     2783.8810
# Dependent Variable:          Cerebellum_Cortex          Log-Likelihood:          -231.54
# Date:                        2021-10-08 06:24           LL-Null:                 -254.02
# No. Observations:            70                         Deviance:                3060.0
# Df Model:                    4                          Pearson chi2:            3.06e+03
# Df Residuals:                65                         Scale:                   47.077
# Method:                      IRLS
# ------------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025   0.975]
# ------------------------------------------------------------------------------------------
# Intercept                                 -6.8385   6.6197 -1.0330 0.3016 -19.8129  6.1360
# C(group, Treatment(reference="NC"))[T.ET] -0.0930   2.3317 -0.0399 0.9682  -4.6630  4.4770
# age                                       -0.3387   0.0969 -3.4965 0.0005  -0.5285 -0.1488
# male                                       4.7231   2.0332  2.3230 0.0202   0.7381  8.7080
# InfraTentorialVol                          0.0000   0.0000  3.8966 0.0001   0.0000  0.0001
# ==========================================================================================
#
#
#
# Cerebellum_White_Matter~age+male+InfraTentorialVol+C(group, Treatment(reference="NC"))
#
#                            Results: Generalized linear model
# ========================================================================================
# Model:                      GLM                           AIC:                  364.0643
# Link Function:              identity                      BIC:                  368.4800
# Dependent Variable:         Cerebellum_White_Matter       Log-Likelihood:       -177.03
# Date:                       2021-10-08 06:24              LL-Null:              -178.04
# No. Observations:           70                            Deviance:             644.63
# Df Model:                   4                             Pearson chi2:         645.
# Df Residuals:               65                            Scale:                9.9174
# Method:                     IRLS
# ----------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025 0.975]
# ----------------------------------------------------------------------------------------
# Intercept                                 -0.2225   3.0383 -0.0732 0.9416 -6.1774 5.7325
# C(group, Treatment(reference="NC"))[T.ET] -0.7639   1.0702 -0.7138 0.4753 -2.8615 1.3336
# age                                       -0.0070   0.0445 -0.1582 0.8743 -0.0942 0.0801
# male                                       0.6638   0.9332  0.7113 0.4769 -1.1652 2.4928
# InfraTentorialVol                          0.0000   0.0000  0.2086 0.8347 -0.0000 0.0000
# ========================================================================================
#
#
#
# Vermis_VI~age+male+InfraTentorialVol+C(group, Treatment(reference="NC"))
#
#                            Results: Generalized linear model
# ========================================================================================
# Model:                        GLM                      AIC:                    -46.8802
# Link Function:                identity                 BIC:                    -274.3336
# Dependent Variable:           Vermis_VI                Log-Likelihood:         28.440
# Date:                         2021-10-08 06:24         LL-Null:                16.553
# No. Observations:             70                       Deviance:               1.8186
# Df Model:                     4                        Pearson chi2:           1.82
# Df Residuals:                 65                       Scale:                  0.027978
# Method:                       IRLS
# ----------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025 0.975]
# ----------------------------------------------------------------------------------------
# Intercept                                 -0.2648   0.1614 -1.6412 0.1008 -0.5811 0.0514
# C(group, Treatment(reference="NC"))[T.ET] -0.0078   0.0568 -0.1377 0.8904 -0.1192 0.1036
# age                                       -0.0039   0.0024 -1.6311 0.1029 -0.0085 0.0008
# male                                       0.1046   0.0496  2.1113 0.0348  0.0075 0.2018
# InfraTentorialVol                          0.0000   0.0000  2.7788 0.0055  0.0000 0.0000
# ========================================================================================
#
#
#
# Vermis_CrusI~age+male+InfraTentorialVol+C(group, Treatment(reference="NC"))
#
#                            Results: Generalized linear model
# ========================================================================================
# Model:                       GLM                      AIC:                    -558.4787
# Link Function:               identity                 BIC:                    -276.1510
# Dependent Variable:          Vermis_CrusI             Log-Likelihood:         284.24
# Date:                        2021-10-08 06:24         LL-Null:                280.64
# No. Observations:            70                       Deviance:               0.0012180
# Df Model:                    4                        Pearson chi2:           0.00122
# Df Residuals:                65                       Scale:                  1.8739e-05
# Method:                      IRLS
# ----------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025 0.975]
# ----------------------------------------------------------------------------------------
# Intercept                                 -0.0036   0.0042 -0.8643 0.3874 -0.0118 0.0046
# C(group, Treatment(reference="NC"))[T.ET]  0.0017   0.0015  1.1314 0.2579 -0.0012 0.0045
# age                                       -0.0001   0.0001 -0.9997 0.3175 -0.0002 0.0001
# male                                       0.0006   0.0013  0.4447 0.6565 -0.0019 0.0031
# InfraTentorialVol                          0.0000   0.0000  1.5116 0.1306 -0.0000 0.0000
# ========================================================================================
#
#
#
# Vermis_CrusII~age+male+InfraTentorialVol+C(group, Treatment(reference="NC"))
#
#                             Results: Generalized linear model
# =========================================================================================
# Model:                       GLM                       AIC:                     -239.6303
# Link Function:               identity                  BIC:                     -276.0363
# Dependent Variable:          Vermis_CrusII             Log-Likelihood:          124.82
# Date:                        2021-10-08 06:24          LL-Null:                 114.41
# No. Observations:            70                        Deviance:                0.11584
# Df Model:                    4                         Pearson chi2:            0.116
# ...
# Link Function:               identity                  BIC:                     -257.7022
# Dependent Variable:          Right_CrusII              Log-Likelihood:          -52.656
# Date:                        2021-10-08 06:24          LL-Null:                 -106.00
# No. Observations:            70                        Deviance:                18.450
# Df Model:                    4                         Pearson chi2:            18.4
# Df Residuals:                65                        Scale:                   0.28385
# Method:                      IRLS
# -----------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025  0.975]
# -----------------------------------------------------------------------------------------
# Intercept                                 -7.5803   0.9996 -7.5832 0.0000 -9.5395 -5.6211
# C(group, Treatment(reference="NC"))[T.ET]  0.0659   0.1775  0.3716 0.7102 -0.2819  0.4138
# age                                        0.0002   0.0073  0.0308 0.9754 -0.0140  0.0145
# male                                       0.1946   0.1525  1.2759 0.2020 -0.1044  0.4936
# cerebellumVol                              0.0001   0.0000  8.6698 0.0000  0.0000  0.0001
# =========================================================================================
#
#
#
# Left_Dentate~age+male+cerebellumVol+C(group, Treatment(reference="NC"))
#
#                             Results: Generalized linear model
# =========================================================================================
# Model:                       GLM                       AIC:                     -72.0209
# Link Function:               identity                  BIC:                     -274.8824
# Dependent Variable:          Left_Dentate              Log-Likelihood:          41.010
# Date:                        2021-10-08 06:24          LL-Null:                 29.324
# No. Observations:            70                        Deviance:                1.2698
# Df Model:                    4                         Pearson chi2:            1.27
# Df Residuals:                65                        Scale:                   0.019536
# Method:                      IRLS
# -----------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025  0.975]
# -----------------------------------------------------------------------------------------
# Intercept                                 -0.7794   0.2622 -2.9720 0.0030 -1.2934 -0.2654
# C(group, Treatment(reference="NC"))[T.ET] -0.0461   0.0466 -0.9902 0.3221 -0.1374  0.0452
# age                                        0.0031   0.0019  1.6102 0.1074 -0.0007  0.0068
# male                                       0.1129   0.0400  2.8213 0.0048  0.0345  0.1913
# cerebellumVol                              0.0000   0.0000  2.3408 0.0192  0.0000  0.0000
# =========================================================================================
#
#
#
# Right_Dentate~age+male+cerebellumVol+C(group, Treatment(reference="NC"))
#
#                             Results: Generalized linear model
# =========================================================================================
# Model:                       GLM                       AIC:                     -50.5716
# Link Function:               identity                  BIC:                     -274.4270
# Dependent Variable:          Right_Dentate             Log-Likelihood:          30.286
# Date:                        2021-10-08 06:24          LL-Null:                 17.304
# No. Observations:            70                        Deviance:                1.7251
# Df Model:                    4                         Pearson chi2:            1.73
# Df Residuals:                65                        Scale:                   0.026541
# Method:                      IRLS
# -----------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025  0.975]
# -----------------------------------------------------------------------------------------
# Intercept                                 -0.9198   0.3057 -3.0093 0.0026 -1.5189 -0.3207
# C(group, Treatment(reference="NC"))[T.ET] -0.0704   0.0543 -1.2976 0.1944 -0.1768  0.0359
# age                                        0.0031   0.0022  1.3877 0.1652 -0.0013  0.0075
# male                                       0.1381   0.0466  2.9611 0.0031  0.0467  0.2295
# cerebellumVol                              0.0000   0.0000  2.5264 0.0115  0.0000  0.0000
# =========================================================================================
#
#
#
# MDTB_1~age+male+cerebellumVol+C(group, Treatment(reference="NC"))
#
#                              Results: Generalized linear model
# ===========================================================================================
# Model:                         GLM                       AIC:                     148.6056
# Link Function:                 identity                  BIC:                     -246.4655
# Dependent Variable:            MDTB_1                    Log-Likelihood:          -69.303
# Date:                          2021-10-08 06:24          LL-Null:                 -141.92
# No. Observations:              70                        Deviance:                29.687
# Df Model:                      4                         Pearson chi2:            29.7
# Df Residuals:                  65                        Scale:                   0.45672
# Method:                        IRLS
# -------------------------------------------------------------------------------------------
#                                            Coef.   Std.Err.    z    P>|z|   [0.025   0.975]
# -------------------------------------------------------------------------------------------
# Intercept                                 -11.2813   1.2680 -8.8970 0.0000 -13.7665 -8.7961
# C(group, Treatment(reference="NC"))[T.ET]   0.2135   0.2251  0.9481 0.3431  -0.2278  0.6547
# age                                         0.0027   0.0092  0.2970 0.7665  -0.0154  0.0208
# male                                        0.3742   0.1935  1.9339 0.0531  -0.0050  0.7535
# cerebellumVol                               0.0001   0.0000  9.9133 0.0000   0.0001  0.0001
# ===========================================================================================
#
#
#
# MDTB_2~age+male+cerebellumVol+C(group, Treatment(reference="NC"))
#
#                              Results: Generalized linear model
# ============================================================================================
# Model:                        GLM                        AIC:                      130.7821
# Link Function:                identity                   BIC:                      -253.1388
# Dependent Variable:           MDTB_2                     Log-Likelihood:           -60.391
# Date:                         2021-10-08 06:24           LL-Null:                  -156.14
# No. Observations:             70                         Deviance:                 23.013
# Df Model:                     4                          Pearson chi2:             23.0
# Df Residuals:                 65                         Scale:                    0.35405
# Method:                       IRLS
# --------------------------------------------------------------------------------------------
#                                            Coef.   Std.Err.    z     P>|z|   [0.025   0.975]
# --------------------------------------------------------------------------------------------
# Intercept                                 -11.7755   1.1164 -10.5477 0.0000 -13.9636 -9.5874
# C(group, Treatment(reference="NC"))[T.ET]   0.2088   0.1982   1.0532 0.2922  -0.1797  0.5973
# age                                         0.0054   0.0081   0.6602 0.5092  -0.0106  0.0213
# male                                        0.3050   0.1704   1.7902 0.0734  -0.0289  0.6389
# cerebellumVol                               0.0001   0.0000  11.6509 0.0000   0.0001  0.0001
# ============================================================================================
#
#
#
# MDTB_4~age+male+cerebellumVol+C(group, Treatment(reference="NC"))
#
#                              Results: Generalized linear model
# ============================================================================================
# Model:                        GLM                        AIC:                      213.8698
# Link Function:                identity                   BIC:                      -200.7343
# Dependent Variable:           MDTB_4                     Log-Likelihood:           -101.93
# Date:                         2021-10-08 06:24           LL-Null:                  -182.44
# No. Observations:             70                         Deviance:                 75.418
# Df Model:                     4                          Pearson chi2:             75.4
# Df Residuals:                 65                         Scale:                    1.1603
# Method:                       IRLS
# --------------------------------------------------------------------------------------------
#                                            Coef.   Std.Err.    z    P>|z|   [0.025   0.975]
# --------------------------------------------------------------------------------------------
# Intercept                                 -19.3937   2.0210 -9.5960 0.0000 -23.3548 -15.4326
# C(group, Treatment(reference="NC"))[T.ET]   0.3333   0.3588  0.9290 0.3529  -0.3700   1.0367
# age                                         0.0035   0.0147  0.2394 0.8108  -0.0253   0.0324
# male                                        0.3771   0.3084  1.2227 0.2214  -0.2274   0.9816
# cerebellumVol                               0.0001   0.0000 10.8560 0.0000   0.0001   0.0002
# ============================================================================================
#
#
#
# MDTB_5~age+male+cerebellumVol+C(group, Treatment(reference="NC"))
#
#                              Results: Generalized linear model
# ===========================================================================================
# Model:                         GLM                       AIC:                     161.5812
# Link Function:                 identity                  BIC:                     -240.4196
# Dependent Variable:            MDTB_5                    Log-Likelihood:          -75.791
# Date:                          2021-10-08 06:24          LL-Null:                 -138.06
# No. Observations:              70                        Deviance:                35.733
# Df Model:                      4                         Pearson chi2:            35.7
# Df Residuals:                  65                        Scale:                   0.54973
# Method:                        IRLS
# -------------------------------------------------------------------------------------------
#                                            Coef.   Std.Err.    z    P>|z|   [0.025   0.975]
# -------------------------------------------------------------------------------------------
# Intercept                                 -11.5939   1.3911 -8.3342 0.0000 -14.3205 -8.8674
# C(group, Treatment(reference="NC"))[T.ET]   0.3030   0.2470  1.2269 0.2199  -0.1811  0.7872
# age                                         0.0035   0.0101  0.3498 0.7265  -0.0163  0.0234
# male                                        0.3486   0.2123  1.6419 0.1006  -0.0675  0.7647
# cerebellumVol                               0.0001   0.0000  9.2291 0.0000   0.0001  0.0001
# ===========================================================================================
# {'Left_Cerebellum_Cortex': {'formula': 'Left_Cerebellum_Cortex~age+male+cerebellumVol+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729f920490>},
#  'Left_Cerebellum_White_Matter': {'formula': 'Left_Cerebellum_White_Matter~age+male+cerebellumVol+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729f926430>},
#  'Right_Cerebellum_Cortex': {'formula': 'Right_Cerebellum_Cortex~age+male+cerebellumVol+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729f9134f0>},
#  'Right_Cerebellum_White_Matter': {'formula': 'Right_Cerebellum_White_Matter~age+male+cerebellumVol+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729f8c5550>},
#  'Cerebellum_Cortex': {'formula': 'Cerebellum_Cortex~age+male+cerebellumVol+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729f8c9bb0>},
#  'Cerebellum_White_Matter': {'formula': 'Cerebellum_White_Matter~age+male+cerebellumVol+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729f8e32b0>},
#  'Vermis_VI': {'formula': 'Vermis_VI~age+male+cerebellumVol+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729f9144f0>},
#  'Vermis_CrusI': {'formula': 'Vermis_CrusI~age+male+cerebellumVol+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729f8ea640>},
#  'Vermis_CrusII': {'formula': 'Vermis_CrusII~age+male+cerebellumVol+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729f8f2e20>},
#  'Left_CrusI': {'formula': 'Left_CrusI~age+male+cerebellumVol+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729f87d3a0>},
#  'Right_CrusI': {'formula': 'Right_CrusI~age+male+cerebellumVol+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729f881430>},
#  'Left_CrusII': {'formula': 'Left_CrusII~age+male+cerebellumVol+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729f887670>},
#  'Right_CrusII': {'formula': 'Right_CrusII~age+male+cerebellumVol+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729f88b9d0>},
#  'Left_Dentate': {'formula': 'Left_Dentate~age+male+cerebellumVol+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729f893b50>},
#  'Right_Dentate': {'formula': 'Right_Dentate~age+male+cerebellumVol+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729f8994c0>},
#  'MDTB_1': {'formula': 'MDTB_1~age+male+cerebellumVol+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729f899ee0>},
#  'MDTB_2': {'formula': 'MDTB_2~age+male+cerebellumVol+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729f88bb50>},
#  'MDTB_4': {'formula': 'MDTB_4~age+male+cerebellumVol+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729f8b12b0>},
#  'MDTB_5': {'formula': 'MDTB_5~age+male+cerebellumVol+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729f8b3400>}}

# %% [markdown]
# # GLM analysis for all 3 datasets
#
# 1. Testing Models: Voi=b0+b1*age+b2*sex+b3*eIV+b4*group for 'Left_Cerebellum_Cortex', 'Left_Cerebellum_White_Matter', 'Right_Cerebellum_Cortex', 'Right_Cerebellum_White_Matter';
#
# 2. Testing Models: Voi=b0+b1*age+b2*sex+b3*eIV+b4*group for 'Vermis_VI', 'Vermis_CrusI', 'Vermis_CrusII', 'Left_CrusI', 'Right_CrusI', 'Left_CrusII', 'Right_CrusII','Left_Dentate', 'Right_Dentate', 'MDTB_1', 'MDTB_2', 'MDTB_4', 'MDTB_5';

# %%
# GLM Model 
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.formula.api import glm
import statsmodels.stats as sts
from utils_et_biomarker.utils import glm_test, rep_model

# basic GLM
tmp_all_df = df_all.copy() 

covariate_model_all_str = '~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))';
covariate_all_dict = glm_test(tmp_all_df, tar_list, covariate_model_all_str);
rep_model(covariate_all_dict)
# Out:
# Left_Cerebellum_Cortex~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))
#
#                                  Results: Generalized linear model
# ===================================================================================================
# Model:                       GLM                            AIC:                    9644.6924
# Link Function:               identity                       BIC:                    8160935032.5918
# Dependent Variable:          Left_Cerebellum_Cortex         Log-Likelihood:         -4815.3
# Date:                        2021-10-08 06:14               LL-Null:                -4966.3
# No. Observations:            495                            Deviance:               8.1609e+09
# Df Model:                    6                              Pearson chi2:           8.16e+09
# Df Residuals:                488                            Scale:                  1.6723e+07
# Method:                      IRLS
# ---------------------------------------------------------------------------------------------------
#                                             Coef.     Std.Err.    z    P>|z|    [0.025     0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                                 27479.0761 1481.8659 18.5436 0.0000 24574.6723 30383.4798
# C(is_mni)[T.1]                             8114.9731  699.4801 11.6014 0.0000  6744.0172  9485.9289
# C(is_adni)[T.1]                            8688.4947  693.4733 12.5290 0.0000  7329.3120 10047.6774
# C(is_ppmi)[T.1]                           10675.6083  574.0013 18.5986 0.0000  9550.5864 11800.6302
# C(group, Treatment(reference="NC"))[T.ET]    90.1589 1030.8237  0.0875 0.9303 -1930.2184  2110.5363
# age                                         -71.5758   18.7146 -3.8246 0.0001  -108.2557   -34.8959
# male                                       2505.2513  428.6402  5.8446 0.0000  1665.1320  3345.3706
# eTIV                                          0.0109    0.0012  9.4240 0.0000     0.0087     0.0132
# ===================================================================================================
#
#
#
# Left_Cerebellum_White_Matter~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))
#
#                                Results: Generalized linear model
# ================================================================================================
# Model:                    GLM                               AIC:                 8904.0505
# Link Function:            identity                          BIC:                 1827796426.7468
# Dependent Variable:       Left_Cerebellum_White_Matter      Log-Likelihood:      -4445.0
# Date:                     2021-10-08 06:14                  LL-Null:             -4528.3
# No. Observations:         495                               Deviance:            1.8278e+09
# Df Model:                 6                                 Pearson chi2:        1.83e+09
# Df Residuals:             488                               Scale:               3.7455e+06
# Method:                   IRLS
# ------------------------------------------------------------------------------------------------
#                                             Coef.   Std.Err.    z    P>|z|    [0.025    0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                                 8688.3876 701.2989 12.3890 0.0000 7313.8671 10062.9081
# C(is_mni)[T.1]                            2352.2668 331.0317  7.1059 0.0000 1703.4565  3001.0771
# C(is_adni)[T.1]                           2693.3470 328.1890  8.2067 0.0000 2050.1085  3336.5856
# C(is_ppmi)[T.1]                           3642.7738 271.6484 13.4099 0.0000 3110.3527  4175.1948
# C(group, Treatment(reference="NC"))[T.ET]  568.2564 487.8414  1.1648 0.2441 -387.8951  1524.4079
# age                                        -50.5876   8.8567 -5.7118 0.0000  -67.9465   -33.2286
# male                                        74.3532 202.8556  0.3665 0.7140 -323.2366   471.9430
# eTIV                                         0.0038   0.0005  6.8700 0.0000    0.0027     0.0049
# ================================================================================================
#
#
#
# Right_Cerebellum_Cortex~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))
#
#                                  Results: Generalized linear model
# ===================================================================================================
# Model:                      GLM                             AIC:                    9665.0311
# Link Function:              identity                        BIC:                    8503237762.4249
# Dependent Variable:         Right_Cerebellum_Cortex         Log-Likelihood:         -4825.5
# Date:                       2021-10-08 06:14                LL-Null:                -4986.1
# No. Observations:           495                             Deviance:               8.5032e+09
# Df Model:                   6                               Pearson chi2:           8.50e+09
# Df Residuals:               488                             Scale:                  1.7425e+07
# Method:                     IRLS
# ---------------------------------------------------------------------------------------------------
#                                             Coef.     Std.Err.    z    P>|z|    [0.025     0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                                 29018.9370 1512.6244 19.1845 0.0000 26054.2477 31983.6263
# C(is_mni)[T.1]                             8996.8855  713.9990 12.6007 0.0000  7597.4732 10396.2978
# C(is_adni)[T.1]                            8958.2551  707.8674 12.6553 0.0000  7570.8604 10345.6498
# C(is_ppmi)[T.1]                           11063.7964  585.9156 18.8829 0.0000  9915.4228 12212.1699
# C(group, Treatment(reference="NC"))[T.ET]  -119.5119 1052.2201 -0.1136 0.9096 -2181.8254  1942.8016
# age                                         -82.9597   19.1030 -4.3427 0.0000  -120.4009   -45.5184
# male                                       2910.6078  437.5373  6.6523 0.0000  2053.0504  3768.1651
# eTIV                                          0.0105    0.0012  8.8417 0.0000     0.0082     0.0128
# ===================================================================================================
#
#
#
# Right_Cerebellum_White_Matter~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))
#
#                                Results: Generalized linear model
# ===============================================================================================
# Model:                    GLM                               AIC:                8865.3505
# Link Function:            identity                          BIC:                1690339270.8833
# Dependent Variable:       Right_Cerebellum_White_Matter     Log-Likelihood:     -4425.7
# Date:                     2021-10-08 06:14                  LL-Null:            -4498.3
# No. Observations:         495                               Deviance:           1.6903e+09
# Df Model:                 6                                 Pearson chi2:       1.69e+09
# Df Residuals:             488                               Scale:              3.4638e+06
# Method:                   IRLS
# -----------------------------------------------------------------------------------------------
#                                             Coef.   Std.Err.    z    P>|z|    [0.025    0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                                 8138.4823 674.4134 12.0675 0.0000 6816.6564 9460.3083
# C(is_mni)[T.1]                            2314.9661 318.3411  7.2720 0.0000 1691.0291 2938.9031
# C(is_adni)[T.1]                           2566.4637 315.6073  8.1318 0.0000 1947.8848 3185.0427
# C(is_ppmi)[T.1]                           3257.0525 261.2343 12.4679 0.0000 2745.0427 3769.0623
# C(group, Treatment(reference="NC"))[T.ET]   14.2771 469.1392  0.0304 0.9757 -905.2187  933.7729
# age                                        -45.6378   8.5172 -5.3583 0.0000  -62.3312  -28.9443
# male                                        85.5983 195.0788  0.4388 0.6608 -296.7492  467.9458
# eTIV                                         0.0037   0.0005  6.9999 0.0000    0.0027    0.0047
# ===============================================================================================
#
#
#
# Cerebellum_Cortex~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))
#
#                                  Results: Generalized linear model
# ===================================================================================================
# Model:                         GLM                        AIC:                     10324.9682
# Link Function:                 identity                   BIC:                     32254370156.8749
# Dependent Variable:            Cerebellum_Cortex          Log-Likelihood:          -5155.5
# Date:                          2021-10-08 06:14           LL-Null:                 -5316.2
# No. Observations:              495                        Deviance:                3.2254e+10
# Df Model:                      6                          Pearson chi2:            3.23e+10
# Df Residuals:                  488                        Scale:                   6.6095e+07
# Method:                        IRLS
# ---------------------------------------------------------------------------------------------------
#                                             Coef.     Std.Err.    z    P>|z|    [0.025     0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                                 56498.0131 2946.0028 19.1779 0.0000 50723.9537 62272.0726
# C(is_mni)[T.1]                            17111.8586 1390.5918 12.3055 0.0000 14386.3488 19837.3683
# C(is_adni)[T.1]                           17646.7498 1378.6499 12.8000 0.0000 14944.6456 20348.8541
# C(is_ppmi)[T.1]                           21739.4047 1141.1353 19.0507 0.0000 19502.8205 23975.9888
# C(group, Treatment(reference="NC"))[T.ET]   -29.3529 2049.3147 -0.0143 0.9886 -4045.9359  3987.2301
# age                                        -154.5355   37.2053 -4.1536 0.0000  -227.4565   -81.6145
# male                                       5415.8591  852.1521  6.3555 0.0000  3745.6716  7086.0465
# eTIV                                          0.0214    0.0023  9.2801 0.0000     0.0169     0.0260
# ===================================================================================================
#
#
#
# Cerebellum_White_Matter~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))
#
#                                  Results: Generalized linear model
# ===================================================================================================
# Model:                      GLM                             AIC:                    9547.0292
# Link Function:              identity                        BIC:                    6699676253.6335
# Dependent Variable:         Cerebellum_White_Matter         Log-Likelihood:         -4766.5
# Date:                       2021-10-08 06:14                LL-Null:                -4848.0
# No. Observations:           495                             Deviance:               6.6997e+09
# Df Model:                   6                               Pearson chi2:           6.70e+09
# Df Residuals:               488                             Scale:                  1.3729e+07
# Method:                     IRLS
# ---------------------------------------------------------------------------------------------------
#                                             Coef.     Std.Err.    z    P>|z|    [0.025     0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                                 16826.8699 1342.6594 12.5325 0.0000 14195.3058 19458.4340
# C(is_mni)[T.1]                             4667.2329  633.7710  7.3642 0.0000  3425.0646  5909.4012
# C(is_adni)[T.1]                            5259.8108  628.3284  8.3711 0.0000  4028.3097  6491.3118
# C(is_ppmi)[T.1]                            6899.8263  520.0796 13.2669 0.0000  5880.4889  7919.1637
# C(group, Treatment(reference="NC"))[T.ET]   582.5335  933.9881  0.6237 0.5328 -1248.0496  2413.1166
# age                                         -96.2253   16.9565 -5.6748 0.0000  -129.4595   -62.9911
# male                                        159.9515  388.3737  0.4118 0.6804  -601.2470   921.1500
# eTIV                                          0.0075    0.0011  7.1044 0.0000     0.0054     0.0095
# ===================================================================================================
#
#
#
# Vermis_VI~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))
#
#                                Results: Generalized linear model
# ===============================================================================================
# Model:                         GLM                       AIC:                     6975.5362
# Link Function:                 identity                  BIC:                     37143848.5565
# Dependent Variable:            Vermis_VI                 Log-Likelihood:          -3480.8
# Date:                          2021-10-08 06:14          LL-Null:                 -3767.1
# No. Observations:              495                       Deviance:                3.7147e+07
# Df Model:                      6                         Pearson chi2:            3.71e+07
# Df Residuals:                  488                       Scale:                   76121.
# Method:                        IRLS
# -----------------------------------------------------------------------------------------------
#                                             Coef.   Std.Err.    z    P>|z|    [0.025    0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                                 1290.9649  99.9770 12.9126 0.0000 1095.0136 1486.9162
# C(is_mni)[T.1]                             560.5360  47.1918 11.8778 0.0000  468.0418  653.0302
# C(is_adni)[T.1]                             82.8117  46.7865  1.7700 0.0767   -8.8882  174.5116
# C(is_ppmi)[T.1]                            647.6172  38.7261 16.7230 0.0000  571.7154  723.5190
# C(group, Treatment(reference="NC"))[T.ET]   28.7402  69.5465  0.4133 0.6794 -107.5685  165.0489
# age                                         -2.1300   1.2626 -1.6870 0.0916   -4.6047    0.3447
# male                                       106.3233  28.9190  3.6766 0.0002   49.6430  163.0036
# eTIV                                         0.0002   0.0001  1.9713 0.0487    0.0000    0.0003
# ===============================================================================================
#
#
#
# Vermis_CrusI~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))
#
#                             Results: Generalized linear model
# =========================================================================================
# Model:                        GLM                      AIC:                    3063.0945
# Link Function:                identity                 BIC:                    10690.2238
# Dependent Variable:           Vermis_CrusI             Log-Likelihood:         -1524.5
# Date:                         2021-10-08 06:14         LL-Null:                -1588.3
# No. Observations:             495                      Deviance:               13718.
# Df Model:                     6                        Pearson chi2:           1.37e+04
# Df Residuals:                 488                      Scale:                  28.111
# Method:                       IRLS
# -----------------------------------------------------------------------------------------
#                                            Coef.  Std.Err.    z    P>|z|   [0.025  0.975]
# -----------------------------------------------------------------------------------------
# Intercept                                 10.8881   1.9213  5.6672 0.0000  7.1225 14.6536
# C(is_mni)[T.1]                             4.6756   0.9069  5.1557 0.0000  2.8981  6.4531
# C(is_adni)[T.1]                            0.8855   0.8991  0.9848 0.3247 -0.8767  2.6477
# C(is_ppmi)[T.1]                            5.3270   0.7442  7.1580 0.0000  3.8684  6.7856
# C(group, Treatment(reference="NC"))[T.ET]  1.4456   1.3365  1.0817 0.2794 -1.1738  4.0651
# age                                       -0.0007   0.0243 -0.0284 0.9773 -0.0482  0.0469
# male                                       1.8345   0.5557  3.3010 0.0010  0.7453  2.9237
# eTIV                                       0.0000   0.0000  1.6896 0.0911 -0.0000  0.0000
# =========================================================================================
#
#
#
# Vermis_CrusII~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))
#
#                              Results: Generalized linear model
# ============================================================================================
# Model:                       GLM                       AIC:                     5505.3793
# Link Function:               identity                  BIC:                     1902703.4141
# Dependent Variable:          Vermis_CrusII             Log-Likelihood:          -2745.7
# Date:                        2021-10-08 06:14          LL-Null:                 -3010.7
# No. Observations:            495                       Deviance:                1.9057e+06
# Df Model:                    6                         Pearson chi2:            1.91e+06
# Df Residuals:                488                       Scale:                   3905.2
# Method:                      IRLS
# --------------------------------------------------------------------------------------------
#                                            Coef.   Std.Err.    z    P>|z|   [0.025   0.975]
# --------------------------------------------------------------------------------------------
# Intercept                                 289.8918  22.6449 12.8017 0.0000 245.5087 334.2749
# C(is_mni)[T.1]                            122.2671  10.6890 11.4386 0.0000 101.3171 143.2171
# C(is_adni)[T.1]                            22.8892  10.5972  2.1599 0.0308   2.1191  43.6593
# C(is_ppmi)[T.1]                           144.7355   8.7715 16.5007 0.0000 127.5436 161.9273
# C(group, Treatment(reference="NC"))[T.ET]  10.8575  15.7523  0.6893 0.4907 -20.0166  41.7315
# age                                        -0.4634   0.2860 -1.6203 0.1052  -1.0239   0.0971
# male                                       29.3239   6.5502  4.4768 0.0000  16.4858  42.1621
# eTIV                                        0.0000   0.0000  1.3258 0.1849  -0.0000   0.0001
# ============================================================================================
#
#
#
# Left_CrusI~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))
#
#                                Results: Generalized linear model
# ================================================================================================
# Model:                        GLM                       AIC:                     8914.8647
# Link Function:                identity                  BIC:                     1868167518.3678
# Dependent Variable:           Left_CrusI                Log-Likelihood:          -4450.4
# Date:                         2021-10-08 06:14          LL-Null:                 -4761.8
# No. Observations:             495                       Deviance:                1.8682e+09
# Df Model:                     6                         Pearson chi2:            1.87e+09
# Df Residuals:                 488                       Scale:                   3.8282e+06
# Method:                       IRLS
# ------------------------------------------------------------------------------------------------
#                                             Coef.   Std.Err.    z    P>|z|    [0.025    0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                                 9025.5099 709.0014 12.7299 0.0000 7635.8926 10415.1272
# C(is_mni)[T.1]                            3894.8270 334.6676 11.6379 0.0000 3238.8907  4550.7633
# C(is_adni)[T.1]                            563.1704 331.7936  1.6974 0.0896  -87.1331  1213.4738
# C(is_ppmi)[T.1]                           4567.5125 274.6320 16.6314 0.0000 4029.2437  5105.7813
# C(group, Treatment(reference="NC"))[T.ET]  645.7915 493.1995  1.3094 0.1904 -320.8618  1612.4447
# age                                        -20.6210   8.9540 -2.3030 0.0213  -38.1706    -3.0714
# male                                       760.4326 205.0837  3.7079 0.0002  358.4760  1162.3892
# eTIV                                         0.0015   0.0006  2.6476 0.0081    0.0004     0.0026
# ================================================================================================
#
#
#
# Right_CrusI~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))
#
#                                Results: Generalized linear model
# ================================================================================================
# Model:                        GLM                       AIC:                     8902.5892
# Link Function:                identity                  BIC:                     1822408825.3443
# Dependent Variable:           Right_CrusI               Log-Likelihood:          -4444.3
# Date:                         2021-10-08 06:14          LL-Null:                 -4763.6
# No. Observations:             495                       Deviance:                1.8224e+09
# Df Model:                     6                         Pearson chi2:            1.82e+09
# Df Residuals:                 488                       Scale:                   3.7345e+06
# Method:                       IRLS
# ------------------------------------------------------------------------------------------------
#                                             Coef.   Std.Err.    z    P>|z|    [0.025    0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                                 9015.7883 700.2645 12.8748 0.0000 7643.2950 10388.2815
# C(is_mni)[T.1]                            3881.0109 330.5435 11.7413 0.0000 3233.1575  4528.8642
# C(is_adni)[T.1]                            580.0883 327.7049  1.7702 0.0767  -62.2016  1222.3781
# C(is_ppmi)[T.1]                           4554.6891 271.2477 16.7916 0.0000 4023.0533  5086.3249
# C(group, Treatment(reference="NC"))[T.ET]  523.7187 487.1219  1.0751 0.2823 -431.0226  1478.4600
# age                                        -24.7395   8.8437 -2.7974 0.0052  -42.0728    -7.4062
# male                                       766.5953 202.5565  3.7846 0.0002  369.5919  1163.5986
# eTIV                                         0.0014   0.0005  2.5034 0.0123    0.0003     0.0025
# ================================================================================================
#
#
#
# Left_CrusII~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))
#
#                                Results: Generalized linear model
# ===============================================================================================
# Model:                       GLM                       AIC:                     8635.4119
# Link Function:               identity                  BIC:                     1062267469.4456
# Dependent Variable:          Left_CrusII               Log-Likelihood:          -4310.7
# Date:                        2021-10-08 06:14          LL-Null:                 -4611.8
# No. Observations:            495                       Deviance:                1.0623e+09
# Df Model:                    6                         Pearson chi2:            1.06e+09
# Df Residuals:                488                       Scale:                   2.1768e+06
# Method:                      IRLS
# -----------------------------------------------------------------------------------------------
#                                             Coef.   Std.Err.    z    P>|z|    [0.025    0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                                 6668.2662 534.6338 12.4726 0.0000 5620.4032 7716.1292
# C(is_mni)[T.1]                            2804.6558 252.3614 11.1136 0.0000 2310.0366 3299.2751
# C(is_adni)[T.1]                            422.1640 250.1942  1.6873 0.0915  -68.2077  912.5356
# C(is_ppmi)[T.1]                           3441.4464 207.0906 16.6181 0.0000 3035.5563 3847.3365
# C(group, Treatment(reference="NC"))[T.ET]  284.0140 371.9049  0.7637 0.4451 -444.9063 1012.9342
# age                                        -17.3352   6.7519 -2.5674 0.0102  -30.5687   -4.1017
# male                                       563.6564 154.6466  3.6448 0.0003  260.5546  866.7582
# eTIV                                         0.0011   0.0004  2.6280 0.0086    0.0003    0.0019
# ===============================================================================================
#
#
#
# Right_CrusII~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))
#
#                                Results: Generalized linear model
# ===============================================================================================
# Model:                        GLM                       AIC:                     8545.0683
# Link Function:                identity                  BIC:                     885053447.6603
# Dependent Variable:           Right_CrusII              Log-Likelihood:          -4265.5
# Date:                         2021-10-08 06:14          LL-Null:                 -4585.0
# No. Observations:             495                       Deviance:                8.8506e+08
# Df Model:                     6                         Pearson chi2:            8.85e+08
# Df Residuals:                 488                       Scale:                   1.8136e+06
# Method:                       IRLS
# -----------------------------------------------------------------------------------------------
#                                             Coef.   Std.Err.    z    P>|z|    [0.025    0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                                 6322.9409 488.0051 12.9567 0.0000 5366.4685 7279.4133
# C(is_mni)[T.1]                            2683.0372 230.3514 11.6476 0.0000 2231.5568 3134.5176
# C(is_adni)[T.1]                            417.9438 228.3732  1.8301 0.0672  -29.6595  865.5471
# C(is_ppmi)[T.1]                           3221.9599 189.0290 17.0448 0.0000 2851.4700 3592.4499
# C(group, Treatment(reference="NC"))[T.ET]  216.5795 339.4688  0.6380 0.5235 -448.7671  881.9260
# age                                        -19.3750   6.1630 -3.1437 0.0017  -31.4544   -7.2956
# male                                       472.2445 141.1589  3.3455 0.0008  195.5781  748.9109
# eTIV                                         0.0010   0.0004  2.6626 0.0078    0.0003    0.0018
# ===============================================================================================
#
#
#
# Left_Dentate~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))
#
#                               Results: Generalized linear model
# =============================================================================================
# Model:                       GLM                       AIC:                     6882.5502
# Link Function:               identity                  BIC:                     30782022.6922
# Dependent Variable:          Left_Dentate              Log-Likelihood:          -3434.3
# Date:                        2021-10-08 06:14          LL-Null:                 -3644.5
# No. Observations:            495                       Deviance:                3.0785e+07
# Df Model:                    6                         Pearson chi2:            3.08e+07
# Df Residuals:                488                       Scale:                   63084.
# Method:                      IRLS
# ---------------------------------------------------------------------------------------------
#                                            Coef.   Std.Err.    z    P>|z|    [0.025   0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                                 754.0247  91.0141  8.2847 0.0000  575.6403 932.4091
# C(is_mni)[T.1]                            342.6748  42.9611  7.9764 0.0000  258.4726 426.8770
# C(is_adni)[T.1]                            -7.7255  42.5922 -0.1814 0.8561  -91.2046  75.7536
# C(is_ppmi)[T.1]                           419.0754  35.2544 11.8872 0.0000  349.9781 488.1727
# C(group, Treatment(reference="NC"))[T.ET]  -7.6300  63.3117 -0.1205 0.9041 -131.7187 116.4588
# age                                        -0.3559   1.1494 -0.3097 0.7568   -2.6088   1.8969
# male                                      133.2056  26.3265  5.0598 0.0000   81.6066 184.8045
# eTIV                                        0.0002   0.0001  3.3106 0.0009    0.0001   0.0004
# =============================================================================================
#
#
#
# Right_Dentate~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))
#
#                               Results: Generalized linear model
# =============================================================================================
# Model:                       GLM                       AIC:                     6954.8614
# Link Function:               identity                  BIC:                     35624274.4228
# Dependent Variable:          Right_Dentate             Log-Likelihood:          -3470.4
# Date:                        2021-10-08 06:14          LL-Null:                 -3696.2
# No. Observations:            495                       Deviance:                3.5627e+07
# Df Model:                    6                         Pearson chi2:            3.56e+07
# Df Residuals:                488                       Scale:                   73007.
# Method:                      IRLS
# ---------------------------------------------------------------------------------------------
#                                            Coef.   Std.Err.    z    P>|z|    [0.025   0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                                 807.2470  97.9107  8.2447 0.0000  615.3454 999.1485
# C(is_mni)[T.1]                            388.2896  46.2165  8.4015 0.0000  297.7070 478.8722
# C(is_adni)[T.1]                           -20.6664  45.8196 -0.4510 0.6520 -110.4711  69.1383
# C(is_ppmi)[T.1]                           439.6237  37.9258 11.5917 0.0000  365.2906 513.9569
# C(group, Treatment(reference="NC"))[T.ET] -30.5657  68.1092 -0.4488 0.6536 -164.0573 102.9259
# age                                        -0.6273   1.2365 -0.5073 0.6119   -3.0508   1.7963
# male                                      153.8588  28.3214  5.4326 0.0000   98.3499 209.3677
# eTIV                                        0.0003   0.0001  3.5940 0.0003    0.0001   0.0004
# =============================================================================================
#
#
#
# MDTB_1~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))
#
#                                 Results: Generalized linear model
# =================================================================================================
# Model:                         GLM                       AIC:                     8901.1042
# Link Function:                 identity                  BIC:                     1816949766.4156
# Dependent Variable:            MDTB_1                    Log-Likelihood:          -4443.6
# Date:                          2021-10-08 06:14          LL-Null:                 -4811.8
# No. Observations:              495                       Deviance:                1.8170e+09
# Df Model:                      6                         Pearson chi2:            1.82e+09
# Df Residuals:                  488                       Scale:                   3.7233e+06
# Method:                        IRLS
# -------------------------------------------------------------------------------------------------
#                                             Coef.    Std.Err.    z    P>|z|    [0.025    0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                                 10026.2770 699.2149 14.3393 0.0000 8655.8410 11396.7130
# C(is_mni)[T.1]                             4242.4023 330.0480 12.8539 0.0000 3595.5201  4889.2846
# C(is_adni)[T.1]                             776.5164 327.2137  2.3731 0.0176  135.1893  1417.8435
# C(is_ppmi)[T.1]                            5007.3582 270.8412 18.4882 0.0000 4476.5193  5538.1972
# C(group, Treatment(reference="NC"))[T.ET]   440.1881 486.3917  0.9050 0.3655 -513.1221  1393.4984
# age                                         -26.8026   8.8304 -3.0353 0.0024  -44.1099    -9.4952
# male                                       1028.4641 202.2529  5.0850 0.0000  632.0558  1424.8724
# eTIV                                          0.0013   0.0005  2.2939 0.0218    0.0002     0.0023
# =================================================================================================
#
#
#
# MDTB_2~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))
#
#                                Results: Generalized linear model
# ================================================================================================
# Model:                        GLM                       AIC:                     8828.8189
# Link Function:                identity                  BIC:                     1570081904.2426
# Dependent Variable:           MDTB_2                    Log-Likelihood:          -4407.4
# Date:                         2021-10-08 06:14          LL-Null:                 -4774.3
# No. Observations:             495                       Deviance:                1.5701e+09
# Df Model:                     6                         Pearson chi2:            1.57e+09
# Df Residuals:                 488                       Scale:                   3.2174e+06
# Method:                       IRLS
# ------------------------------------------------------------------------------------------------
#                                             Coef.   Std.Err.    z    P>|z|    [0.025    0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                                 9253.6940 649.9807 14.2369 0.0000 7979.7554 10527.6327
# C(is_mni)[T.1]                            3929.1599 306.8082 12.8066 0.0000 3327.8270  4530.4929
# C(is_adni)[T.1]                            727.3120 304.1734  2.3911 0.0168  131.1430  1323.4810
# C(is_ppmi)[T.1]                           4597.2221 251.7703 18.2596 0.0000 4103.7614  5090.6827
# C(group, Treatment(reference="NC"))[T.ET]  443.2221 452.1431  0.9803 0.3270 -442.9621  1329.4063
# age                                        -25.1494   8.2086 -3.0638 0.0022  -41.2381    -9.0608
# male                                      1005.8628 188.0115  5.3500 0.0000  637.3670  1374.3585
# eTIV                                         0.0012   0.0005  2.4294 0.0151    0.0002     0.0022
# ================================================================================================
#
#
#
# MDTB_4~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))
#
#                                  Results: Generalized linear model
# ===================================================================================================
# Model:                         GLM                        AIC:                      9359.9251
# Link Function:                 identity                   BIC:                      4590876210.4159
# Dependent Variable:            MDTB_4                     Log-Likelihood:           -4673.0
# Date:                          2021-10-08 06:14           LL-Null:                  -5013.0
# No. Observations:              495                        Deviance:                 4.5909e+09
# Df Model:                      6                          Pearson chi2:             4.59e+09
# Df Residuals:                  488                        Scale:                    9.4075e+06
# Method:                        IRLS
# ---------------------------------------------------------------------------------------------------
#                                             Coef.     Std.Err.    z    P>|z|    [0.025     0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                                 15052.8110 1111.4420 13.5435 0.0000 12874.4247 17231.1972
# C(is_mni)[T.1]                             6464.0117  524.6302 12.3211 0.0000  5435.7554  7492.2680
# C(is_adni)[T.1]                             994.1449  520.1249  1.9114 0.0560   -25.2812  2013.5709
# C(is_ppmi)[T.1]                            7594.6544  430.5175 17.6408 0.0000  6750.8557  8438.4532
# C(group, Treatment(reference="NC"))[T.ET]   583.4059  773.1474  0.7546 0.4505  -931.9351  2098.7469
# age                                         -38.3656   14.0365 -2.7333 0.0063   -65.8766   -10.8546
# male                                       1282.7053  321.4924  3.9898 0.0001   652.5917  1912.8189
# eTIV                                          0.0022    0.0009  2.5027 0.0123     0.0005     0.0039
# ===================================================================================================
#
#
#
# MDTB_5~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))
#
#                                Results: Generalized linear model
# ================================================================================================
# Model:                        GLM                       AIC:                     8924.9016
# Link Function:                identity                  BIC:                     1906434549.9527
# Dependent Variable:           MDTB_5                    Log-Likelihood:          -4455.5
# Date:                         2021-10-08 06:14          LL-Null:                 -4795.6
# No. Observations:             495                       Deviance:                1.9064e+09
# Df Model:                     6                         Pearson chi2:            1.91e+09
# Df Residuals:                 488                       Scale:                   3.9066e+06
# Method:                       IRLS
# ------------------------------------------------------------------------------------------------
#                                             Coef.   Std.Err.    z    P>|z|    [0.025    0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                                 9287.2326 716.2261 12.9669 0.0000 7883.4552 10691.0100
# C(is_mni)[T.1]                            3960.7433 338.0778 11.7155 0.0000 3298.1230  4623.3636
# C(is_adni)[T.1]                            542.2478 335.1745  1.6178 0.1057 -114.6822  1199.1777
# C(is_ppmi)[T.1]                           4784.2416 277.4305 17.2448 0.0000 4240.4879  5327.9953
# C(group, Treatment(reference="NC"))[T.ET]  507.3279 498.2251  1.0183 0.3085 -469.1754  1483.8313
# age                                        -24.8976   9.0453 -2.7526 0.0059  -42.6260    -7.1692
# male                                       807.9193 207.1735  3.8997 0.0001  401.8668  1213.9719
# eTIV                                         0.0016   0.0006  2.8887 0.0039    0.0005     0.0027
# ================================================================================================
# {'Left_Cerebellum_Cortex': {'formula': 'Left_Cerebellum_Cortex~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729fd651f0>},
#  'Left_Cerebellum_White_Matter': {'formula': 'Left_Cerebellum_White_Matter~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729fd0eeb0>},
#  'Right_Cerebellum_Cortex': {'formula': 'Right_Cerebellum_Cortex~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f72a34ef670>},
#  'Right_Cerebellum_White_Matter': {'formula': 'Right_Cerebellum_White_Matter~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729fd2e6a0>},
#  'Cerebellum_Cortex': {'formula': 'Cerebellum_Cortex~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729fd35910>},
#  'Cerebellum_White_Matter': {'formula': 'Cerebellum_White_Matter~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729fcbf6d0>},
#  'Vermis_VI': {'formula': 'Vermis_VI~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729fcca4f0>},
#  'Vermis_CrusI': {'formula': 'Vermis_CrusI~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729fcd3280>},
#  'Vermis_CrusII': {'formula': 'Vermis_CrusII~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729fcdc790>},
#  'Left_CrusI': {'formula': 'Left_CrusI~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729fce36a0>},
#  'Right_CrusI': {'formula': 'Right_CrusI~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729fd261c0>},
#  'Left_CrusII': {'formula': 'Left_CrusII~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729fd26af0>},
#  'Right_CrusII': {'formula': 'Right_CrusII~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729fd1e0a0>},
#  'Left_Dentate': {'formula': 'Left_Dentate~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729fd5eac0>},
#  'Right_Dentate': {'formula': 'Right_Dentate~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729fd74820>},
#  'MDTB_1': {'formula': 'MDTB_1~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729fc80880>},
#  'MDTB_2': {'formula': 'MDTB_2~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729fc847f0>},
#  'MDTB_4': {'formula': 'MDTB_4~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729fc8e4c0>},
#  'MDTB_5': {'formula': 'MDTB_5~age+male+eTIV+C(is_mni)+C(is_adni)+C(is_ppmi)+C(group, Treatment(reference="NC"))',
#   'res': <statsmodels.genmod.generalized_linear_model.GLMResultsWrapper at 0x7f729fc95520>}}
